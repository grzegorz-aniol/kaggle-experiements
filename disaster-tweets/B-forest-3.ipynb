# %% [markdown]
# # Random forest & Boosted trees + location check hipotesis

# %% [markdown]
# In this notebook I'm going to verify the hypotesis that detailed (cleaned) locations i.e. country/state have correlation with target classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import feature_extraction, ensemble, model_selection, pipeline, compose, preprocessing
from sklearn.experimental import enable_halving_search_cv
import xgboost as xg

# %%
df_train = pd.read_csv('./train_enriched.csv')
df_train.fillna({'keyword':"", 'country': "", 'state': "", 'city': "", 'location_phrase': ""}, inplace=True)
df_train.shape
# Out:
# (7613, 20)

# %%
df_train.sample(n=5)
# Out:
#         id               keyword  positive_factor          location  \
# 1018  1018           body%20bags         0.024390     Austin, Texas
# 6343  6343  structural%20failure         0.657143         Indonesia
# 5428  5428                police         0.567568  Kansas City, Mo.
# 2991  2991          dust%20storm         0.666667             Idaho
# 693    693               blazing         0.029412         Lima-Peru
#
#             country     state         city  missing_location  \
# 1018  United States     Texas       Austin                 0
# 6343      Indonesia                                        0
# 5428  United States  Missouri  Kansas City                 0
# 2991                    Idaho                              0
# 693                                                        0
#
#                                                    text  \
# 1018  @FoxNews @JenGriffinFNC When you call to repor...
# 6343  Investigators have said a Virgin Galactic spac...
# 5428  Police: Gunman reported dead at Nashville area...
# 2991  @NWSPocatello BG-16: So far brunt of storm jus...
# 693   Oh my heart racing And my temperature is blazi...
#
#                                              clean_text  text_length  \
# 1018  foxnews jengriffinfnc call report dangerous ac...           88
# 6343  investigator said virgin galactic spaceship cr...          119
# 5428  police gunman reported dead nashville area the...          116
# 2991  nwspocatello bg16 far brunt storm north grayed...          109
# 693   oh heart racing temperature blazing roof video...           81
#
#       upper_text_factor  tags_count  punct_factor  ann_count  urls_count  \
# 1018           0.090909           0      0.034091          2           0
# 6343           0.075630           0      0.075630          0           1
# 5428           0.077586           0      0.086207          0           1
# 2991           0.091743           0      0.082569          1           0
# 693            0.111111           1      0.012346          0           0
#
#       tokens_count  stop_words_factor  clean_tokens_factor  target
# 1018            17           0.294118             0.705882       1
# 6343            18           0.333333             0.611111       1
# 5428            21           0.333333             0.619048       1
# 2991            26           0.269231             0.730769       0
# 693             15           0.333333             0.666667       0

# %% [markdown]
# ## Features selection

# %%
categorical_features = [
    'country',
    'state',
]
numerical_features = [
    'text_length', 
    'urls_count',
    'stop_words_factor',
    'clean_tokens_factor',
    'positive_factor'
]

vc_text = feature_extraction.text.TfidfVectorizer(max_features=2000)

transformer = compose.ColumnTransformer(transformers=[
    ('text_vector', vc_text, 'clean_text'),
    ('one_hot', preprocessing.OneHotEncoder(handle_unknown='ignore'), categorical_features),
    ('numerical', preprocessing.StandardScaler(), numerical_features)
], remainder='drop')

X_train = transformer.fit_transform(df_train)
print('X_train shape', X_train.shape)

Y_train = df_train['target']
# X_train.columns = X_train.columns.astype(str)

X_train.shape, Y_train.shape

X_test = transformer.transform(pd.read_csv('./test_enriched.csv', index_col='id'))
print('X_test shape', X_test.shape)
# Out:
# X_train shape (7613, 2172)
# X_test shape (3263, 2172)

# %%
vc_text.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 vc_text.get_feature_names_out()
#
# File ~/anaconda3/envs/machine-learning-1/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:1479, in CountVectorizer.get_feature_names_out(self, input_features)
#    1466 def get_feature_names_out(self, input_features=None):
#    1467     """Get output feature names for transformation.
#    1468
#    1469     Parameters
#    (...)
#    1477         Transformed feature names.
#    1478     """
# -> 1479     self._check_vocabulary()
#    1480     return np.asarray(
#    1481         [t for t, i in sorted(self.vocabulary_.items(), key=itemgetter(1))],
#    1482         dtype=object,
#    1483     )
#
# File ~/anaconda3/envs/machine-learning-1/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:508, in _VectorizerMixin._check_vocabulary(self)
#     506     self._validate_vocabulary()
#     507     if not self.fixed_vocabulary_:
# --> 508         raise NotFittedError("Vocabulary not fitted or provided")
#     510 if len(self.vocabulary_) == 0:
#     511     raise ValueError("Vocabulary is empty")
#
# NotFittedError: Vocabulary not fitted or provided

# %% [markdown]
# ## Model selection

# %% [markdown]
# ### Random forest

# %%
params_rf = {
    'n_estimators': [100, 200],
    'max_depth': [100, 200],
    'ccp_alpha': np.geomspace(0.005, 0.00001, 10)
}
model_rf = ensemble.RandomForestClassifier(n_jobs=-1)

# %%
halving_rf = model_selection.HalvingGridSearchCV(estimator=model_rf, param_grid=params_rf, cv=5, n_jobs=2, scoring='f1', verbose=3)
halving_rf.fit(X_train, Y_train)
print('Best params', halving_rf.best_params_, halving_rf.best_score_)
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 281
# max_resources_: 7613
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 40
# n_resources: 281
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.948, test=0.214) total time=   0.4s
# [CV 2/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.925, test=0.529) total time=   0.4s
# [CV 4/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.968, test=0.667) total time=   0.4s
# [CV 3/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.962, test=0.600) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.980, test=0.679) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.005, max_depth=100, n_estimators=200;, score=(train=0.960, test=0.214) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.005, max_depth=100, n_estimators=200;, score=(train=0.951, test=0.438) total time=   0.7s
# [CV 3/5] END ccp_alpha=0.005, max_depth=100, n_estimators=200;, score=(train=0.973, test=0.526) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.005, max_depth=100, n_estimators=200;, score=(train=0.974, test=0.636) total time=   0.7s
# [CV 5/5] END ccp_alpha=0.005, max_depth=100, n_estimators=200;, score=(train=0.975, test=0.702) total time=   0.7s
# [CV 1/5] END ccp_alpha=0.005, max_depth=200, n_estimators=100;, score=(train=0.954, test=0.214) total time=   0.4s
# [CV 2/5] END ccp_alpha=0.005, max_depth=200, n_estimators=100;, score=(train=0.945, test=0.514) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.005, max_depth=200, n_estimators=100;, score=(train=0.957, test=0.526) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.005, max_depth=200, n_estimators=100;, score=(train=0.984, test=0.585) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.005, max_depth=200, n_estimators=100;, score=(train=0.975, test=0.746) total time=   0.3s
# [CV 2/5] END ccp_alpha=0.005, max_depth=200, n_estimators=200;, score=(train=0.951, test=0.333) total time=   0.7s
# [CV 1/5] END ccp_alpha=0.005, max_depth=200, n_estimators=200;, score=(train=0.954, test=0.267) total time=   0.7s
# [CV 3/5] END ccp_alpha=0.005, max_depth=200, n_estimators=200;, score=(train=0.962, test=0.541) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.005, max_depth=200, n_estimators=200;, score=(train=0.963, test=0.651) total time=   0.7s
# [CV 1/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=100;, score=(train=0.994, test=0.207) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.005, max_depth=200, n_estimators=200;, score=(train=0.990, test=0.702) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=100;, score=(train=0.976, test=0.276) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=100;, score=(train=0.989, test=0.650) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=100;, score=(train=0.995, test=0.698) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.4s
# [CV 1/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=200;, score=(train=0.994, test=0.214) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=200;, score=(train=0.988, test=0.375) total time=   0.7s
# [CV 3/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=200;, score=(train=0.995, test=0.600) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.651) total time=   0.7s
# [CV 1/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.994, test=0.214) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.0025065966118386304, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.988, test=0.529) total time=   0.4s
# [CV 3/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.989, test=0.632) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.682) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.995, test=0.679) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=200;, score=(train=0.994, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=200;, score=(train=0.976, test=0.438) total time=   0.7s
# [CV 3/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=200;, score=(train=0.989, test=0.513) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.7s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=100;, score=(train=0.994, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=100;, score=(train=0.994, test=0.485) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.541) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.605) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.724) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.994, test=0.556) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.995, test=0.541) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.994, test=0.529) total time=   0.5s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.457) total time=   0.5s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.727) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.733) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.8s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=200;, score=(train=0.994, test=0.485) total time=   0.8s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.550) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.634) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.276) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.364) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.682) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.485) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.579) total time=   0.7s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.651) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.702) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.564) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.652) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.724) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.276) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.457) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.579) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.636) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.595) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.424) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.667) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.690) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.514) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.486) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.667) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.364) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0003158113834850658, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.375) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.513) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.619) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.759) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.7s
# [CV 2/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.514) total time=   0.7s
# [CV 3/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.585) total time=   1.1s
# [CV 4/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.682) total time=   1.2s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.207) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.8s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.375) total time=   0.4s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.605) total time=   0.4s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.651) total time=   0.4s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.276) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.424) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.634) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.276) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.667) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.615) total time=   0.3s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.634) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.754) total time=   0.3s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.556) total time=   0.6s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.541) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.6s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.690) total time=   0.6s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.286) total time=   0.3s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.667) total time=   0.3s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.3s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.276) total time=   0.6s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.471) total time=   0.6s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.600) total time=   0.6s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.667) total time=   0.6s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.767) total time=   0.6s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.438) total time=   0.3s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.514) total time=   0.4s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.634) total time=   0.4s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.655) total time=   0.4s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.8s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.500) total time=   0.7s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.500) total time=   0.7s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.8s
# [CV 1/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.200) total time=   0.4s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.746) total time=   0.7s
# [CV 2/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.412) total time=   0.4s
# [CV 3/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.615) total time=   0.3s
# [CV 4/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.667) total time=   0.3s
# [CV 5/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.724) total time=   0.3s
# [CV 1/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.387) total time=   0.6s
# [CV 3/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.564) total time=   0.6s
# [CV 4/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.6s
# [CV 1/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.200) total time=   0.3s
# [CV 5/5] END ccp_alpha=3.978974098492568e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.746) total time=   0.6s
# [CV 2/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.438) total time=   0.3s
# [CV 3/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.412) total time=   0.3s
# [CV 4/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.652) total time=   0.3s
# [CV 5/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.3s
# [CV 1/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.207) total time=   0.6s
# [CV 2/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.471) total time=   0.7s
# [CV 3/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.541) total time=   0.7s
# [CV 4/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.651) total time=   0.7s
# [CV 1/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.4s
# [CV 5/5] END ccp_alpha=3.978974098492568e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.724) total time=   0.8s
# [CV 2/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.457) total time=   0.4s
# [CV 3/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.541) total time=   0.3s
# [CV 4/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.636) total time=   0.3s
# [CV 5/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.712) total time=   0.3s
# [CV 1/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.485) total time=   0.6s
# [CV 3/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.600) total time=   0.6s
# [CV 4/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.651) total time=   0.6s
# [CV 1/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.276) total time=   0.3s
# [CV 5/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.733) total time=   0.6s
# [CV 2/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.514) total time=   0.3s
# [CV 3/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 4/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.698) total time=   0.3s
# [CV 5/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.630) total time=   0.3s
# [CV 1/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.424) total time=   0.6s
# [CV 3/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.526) total time=   0.6s
# [CV 4/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.682) total time=   0.6s
# [CV 1/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=1.9947365987750262e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.702) total time=   0.6s
# [CV 2/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.424) total time=   0.3s
# [CV 3/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.585) total time=   0.3s
# [CV 4/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.526) total time=   0.3s
# [CV 5/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=100;, score=(train=1.000, test=0.702) total time=   0.3s
# [CV 1/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.485) total time=   0.6s
# [CV 3/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.541) total time=   0.6s
# [CV 4/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.711) total time=   0.6s
# [CV 1/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.214) total time=   0.3s
# [CV 5/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.679) total time=   0.6s
# [CV 2/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.529) total time=   0.3s
# [CV 3/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.474) total time=   0.3s
# [CV 4/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.667) total time=   0.3s
# [CV 5/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.702) total time=   0.3s
# [CV 1/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.214) total time=   0.6s
# [CV 2/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.556) total time=   0.6s
# [CV 3/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.457) total time=   0.6s
# [CV 4/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.634) total time=   0.6s
# [CV 5/5] END ccp_alpha=1e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.733) total time=   0.5s
# ----------
# iter: 1
# n_candidates: 14
# n_resources: 843
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.646) total time=   1.0s
# [CV 2/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.604) total time=   1.0s
# [CV 3/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.700) total time=   1.1s
# [CV 4/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.603) total time=   1.1s
# [CV 5/5] END ccp_alpha=1e-05, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.689) total time=   1.3s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=0.996, test=0.632) total time=   1.3s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=0.992, test=0.628) total time=   1.2s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.687) total time=   1.2s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=0.993, test=0.672) total time=   1.0s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=100, n_estimators=200;, score=(train=0.996, test=0.609) total time=   1.0s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.633) total time=   1.0s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.656) total time=   1.1s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.700) total time=   1.2s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.589) total time=   1.2s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.984, test=0.633) total time=   0.5s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.678) total time=   1.0s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.987, test=0.588) total time=   0.5s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.981, test=0.657) total time=   0.5s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.981, test=0.643) total time=   0.5s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=200, n_estimators=100;, score=(train=0.978, test=0.678) total time=   0.5s
# [CV 1/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.650) total time=   1.1s
# [CV 2/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=0.995, test=0.607) total time=   1.0s
# [CV 3/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.705) total time=   1.0s
# [CV 4/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=0.994, test=0.614) total time=   1.0s
# [CV 5/5] END ccp_alpha=0.0006299605249474369, max_depth=200, n_estimators=200;, score=(train=0.993, test=0.661) total time=   1.0s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.656) total time=   1.0s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.609) total time=   1.0s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.717) total time=   1.0s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.638) total time=   1.0s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.655) total time=   1.0s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.656) total time=   1.0s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.647) total time=   1.0s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.691) total time=   1.0s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.602) total time=   1.0s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.677) total time=   1.0s
# [CV 1/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.633) total time=   1.0s
# [CV 2/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.629) total time=   1.0s
# [CV 3/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.691) total time=   1.0s
# [CV 4/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.609) total time=   1.0s
# [CV 5/5] END ccp_alpha=1.9947365987750262e-05, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.667) total time=   1.1s
# [CV 1/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.771, test=0.628) total time=   0.5s
# [CV 3/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.780, test=0.690) total time=   0.5s
# [CV 2/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.823, test=0.603) total time=   0.5s
# [CV 4/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.771, test=0.569) total time=   0.6s
# [CV 5/5] END ccp_alpha=0.005, max_depth=100, n_estimators=100;, score=(train=0.801, test=0.650) total time=   0.6s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.987, test=0.656) total time=   1.1s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.985, test=0.607) total time=   1.1s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.983, test=0.626) total time=   1.0s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.979, test=0.691) total time=   1.1s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.987, test=0.677) total time=   1.0s
# [CV 1/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.639) total time=   1.0s
# [CV 2/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.623) total time=   1.0s
# [CV 3/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.667) total time=   1.0s
# [CV 4/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=1.000, test=0.577) total time=   1.0s
# [CV 5/5] END ccp_alpha=0.0003158113834850658, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.683) total time=   1.0s
# [CV 1/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.917, test=0.639) total time=   0.5s
# [CV 2/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.928, test=0.599) total time=   0.5s
# [CV 3/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.900, test=0.676) total time=   0.6s
# [CV 4/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.909, test=0.595) total time=   0.6s
# [CV 5/5] END ccp_alpha=0.0025065966118386304, max_depth=200, n_estimators=100;, score=(train=0.927, test=0.688) total time=   0.5s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.667) total time=   0.5s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=0.998, test=0.613) total time=   0.5s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=0.998, test=0.696) total time=   0.5s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=1.000, test=0.602) total time=   0.5s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=100;, score=(train=0.997, test=0.655) total time=   0.5s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.661) total time=   1.0s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.613) total time=   1.0s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.662) total time=   1.0s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=1.000, test=0.621) total time=   1.0s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.689) total time=   0.7s
# ----------
# iter: 2
# n_candidates: 5
# n_resources: 2529
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.995, test=0.633) total time=   2.2s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.992, test=0.624) total time=   2.3s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.998, test=0.692) total time=   2.2s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.656) total time=   2.3s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=100, n_estimators=200;, score=(train=0.997, test=0.760) total time=   2.4s
# [CV 1/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.993, test=0.648) total time=   2.4s
# [CV 2/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.995, test=0.622) total time=   2.5s
# [CV 3/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.998, test=0.691) total time=   2.4s
# [CV 4/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.619) total time=   2.4s
# [CV 5/5] END ccp_alpha=7.937005259841008e-05, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.772) total time=   2.3s
# [CV 2/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.862, test=0.615) total time=   2.5s
# [CV 1/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.833, test=0.624) total time=   2.6s
# [CV 4/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.859, test=0.656) total time=   2.3s
# [CV 3/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.859, test=0.689) total time=   2.4s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.990, test=0.627) total time=   2.3s
# [CV 5/5] END ccp_alpha=0.0012566053148961804, max_depth=100, n_estimators=200;, score=(train=0.863, test=0.758) total time=   2.4s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.993, test=0.648) total time=   2.4s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.996, test=0.695) total time=   2.4s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.996, test=0.638) total time=   2.2s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.995, test=0.768) total time=   2.3s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.993, test=0.642) total time=   2.4s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.992, test=0.635) total time=   2.5s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.995, test=0.700) total time=   2.6s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.997, test=0.665) total time=   2.6s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.996, test=0.758) total time=   1.8s
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 7587
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.952, test=0.616) total time=   6.3s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.948, test=0.673) total time=   6.3s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.953, test=0.688) total time=   6.0s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.948, test=0.666) total time=   6.1s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=100, n_estimators=200;, score=(train=0.948, test=0.747) total time=   6.4s
# [CV 1/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.969, test=0.662) total time=   7.1s
# [CV 2/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.969, test=0.609) total time=   7.2s
# [CV 3/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.971, test=0.683) total time=   6.9s
# [CV 4/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.969, test=0.670) total time=   7.0s
# [CV 5/5] END ccp_alpha=0.00015832234876474746, max_depth=200, n_estimators=200;, score=(train=0.968, test=0.741) total time=   7.3s
# Best params {'ccp_alpha': 0.00015832234876474746, 'max_depth': 100, 'n_estimators': 200} 0.6779505048968122

# %%
Y_predict = halving_rf.best_estimator_.predict(X_train)
df_wrong_predictions = pd.DataFrame({'target': Y_train.to_numpy(), 'predict': Y_predict, 'keyword': df_train['keyword'], 'location': df_train['location'], 'text': df_train['text']}).query('target != predict')

# %%
with pd.option_context('display.max_colwidth', 200):
    print(df_wrong_predictions.query('target==1').sample(n=10))
# Out:
#       target  predict         keyword                   location  \
# 4171       1        0            harm                         va
# 3134       1        0       emergency                        NaN
# 548        1        0          battle                        NaN
# 2554       1        0         destroy            Jerseyville, IL
# 6831       1        0         trapped                Puerto Rico
# 2342       1        0      demolition                        NaN
# 988        1        0  body%20bagging  ÌÏT: 39.982988,-75.261624
# 4770       1        0       lightning                        NaN
# 7091       1        0        upheaval                Connecticut
# 4311       1        0        hellfire           Denver, Colorado
#
#                                                                                                                                                  text
# 4171                     @malistkiss Sunnis continue to believe they are more righteous and they continually harm Shias. Defeats the ideals of Islam.
# 3134                                                     Emergency Flow  http://t.co/lH9mrYpDrJ mp3 http://t.co/PqhuthSS3i rar http://t.co/0iW6dRf5X9
# 548                    CIVIL WAR GENERAL BATTLE BULL RUN HERO COLONEL 2nd NEW HAMPSHIRE LETTER SIGNED ! http://t.co/Ot0tFFpBYB http://t.co/zaRBwep9LD
# 2554  Dem FLATLINERS who destroy creativity-balance-longevity &amp; TRUTH stand with Lucifer in all his flames of destruction https://t.co/WcFpZNsN9u
# 6831                                                                    Hollywood Movie About Trapped Miners Released in Chile http://t.co/qkrLtrd39B
# 2342                                                                      #download &amp; #watch Demolition Frog (2002) http://t.co/81nEizeknm #movie
# 988                                                  @fuckyeahcarey @BornVerified drake killing this dude and tea bagging the dead body at this point
# 4770                      World War II book LIGHTNING JOE An Autobiography by General J. Lawton Collins http://t.co/R4khEH7iaf http://t.co/qSZgJfUutu
# 7091                                                                  A look at state actions a year after Ferguson's upheaval http://t.co/vXUFtVT9AU
# 4311                            @gg_keeponrockin @StrawberrySoryu Oh okay I just got the message twice and got suspicious. Sorry.  I'll check it out!

# %% [markdown]
# #### Generate output

# %%
Y_test_predict = halving_rf.best_estimator_.predict(X_test)

df_example = pd.read_csv('./sample_submission.csv')
df_example['target'] = Y_test_predict

df_example.to_csv('./b-forest-3-submission.csv', index=False)

# %% [markdown]
# ### Boosted trees

# %%
params_xgb = {
    'learning_rate': np.geomspace(0.01, 0.3, 5),
    'n_estimators': [100, 200],
    'max_depth': [50, 70]
}
model_xgb = xg.XGBClassifier()
xgb_selection = model_selection.HalvingGridSearchCV(model_xgb, params_xgb, cv=5, n_jobs=-1, scoring='f1', verbose=3)
xgb_selection.fit(X_train, Y_train)
print('XGB best model', xgb_selection.best_params_, xgb_selection.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 845
# max_resources_: 7613
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 845
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 4/5] END learning_rate=0.01, max_depth=50, n_estimators=100;, score=(train=0.908, test=0.619) total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=50, n_estimators=100;, score=(train=0.912, test=0.579) total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=50, n_estimators=100;, score=(train=0.897, test=0.574) total time=   0.6s
# [CV 5/5] END learning_rate=0.01, max_depth=50, n_estimators=100;, score=(train=0.883, test=0.730) total time=   0.7s
# [CV 3/5] END learning_rate=0.01, max_depth=50, n_estimators=100;, score=(train=0.901, test=0.615) total time=   0.7s
# [CV 1/5] END learning_rate=0.01, max_depth=50, n_estimators=200;, score=(train=0.930, test=0.589) total time=   1.1s
# [CV 1/5] END learning_rate=0.01, max_depth=70, n_estimators=100;, score=(train=0.897, test=0.574) total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=50, n_estimators=200;, score=(train=0.945, test=0.592) total time=   1.1s
# [CV 2/5] END learning_rate=0.01, max_depth=70, n_estimators=100;, score=(train=0.912, test=0.579) total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=70, n_estimators=100;, score=(train=0.901, test=0.615) total time=   0.8s
# [CV 4/5] END learning_rate=0.01, max_depth=50, n_estimators=200;, score=(train=0.944, test=0.619) total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=70, n_estimators=100;, score=(train=0.908, test=0.619) total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=50, n_estimators=200;, score=(train=0.949, test=0.600) total time=   1.6s
# [CV 5/5] END learning_rate=0.01, max_depth=50, n_estimators=200;, score=(train=0.926, test=0.737) total time=   1.2s
# [CV 5/5] END learning_rate=0.01, max_depth=70, n_estimators=100;, score=(train=0.883, test=0.730) total time=   0.9s
# [CV 1/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=100;, score=(train=0.944, test=0.594) total time=   1.7s
# [CV 2/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=100;, score=(train=0.947, test=0.581) total time=   1.7s
# [CV 4/5] END learning_rate=0.01, max_depth=70, n_estimators=200;, score=(train=0.944, test=0.619) total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=70, n_estimators=200;, score=(train=0.945, test=0.592) total time=   2.8s
# [CV 1/5] END learning_rate=0.01, max_depth=70, n_estimators=200;, score=(train=0.930, test=0.589) total time=   3.0s
# [CV 3/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=100;, score=(train=0.958, test=0.590) total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=70, n_estimators=200;, score=(train=0.949, test=0.600) total time=   3.4s
# [CV 5/5] END learning_rate=0.01, max_depth=70, n_estimators=200;, score=(train=0.926, test=0.737) total time=   3.8s
# [CV 5/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=100;, score=(train=0.944, test=0.737) total time=   2.8s
# [CV 4/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=100;, score=(train=0.963, test=0.615) total time=   2.9s
# [CV 1/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=100;, score=(train=0.944, test=0.594) total time=   2.3s
# [CV 1/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=200;, score=(train=0.985, test=0.587) total time=   4.5s
# [CV 2/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=200;, score=(train=0.984, test=0.569) total time=   4.5s
# [CV 2/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=100;, score=(train=0.947, test=0.581) total time=   2.4s
# [CV 3/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=100;, score=(train=0.958, test=0.590) total time=   2.9s
# [CV 4/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=100;, score=(train=0.963, test=0.615) total time=   1.9s
# [CV 5/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=200;, score=(train=0.982, test=0.742) total time=   4.8s
# [CV 4/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=200;, score=(train=0.988, test=0.636) total time=   5.3s
# [CV 3/5] END learning_rate=0.023403473193207163, max_depth=50, n_estimators=200;, score=(train=0.986, test=0.622) total time=   5.9s
# [CV 5/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=100;, score=(train=0.944, test=0.737) total time=   2.1s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.987, test=0.587) total time=   1.8s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.990, test=0.585) total time=   2.1s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.993, test=0.638) total time=   2.1s
# [CV 2/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=200;, score=(train=0.984, test=0.569) total time=   4.4s
# [CV 1/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=200;, score=(train=0.985, test=0.587) total time=   4.8s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.992, test=0.646) total time=   1.9s
# [CV 4/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=200;, score=(train=0.988, test=0.636) total time=   4.4s
# [CV 3/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=200;, score=(train=0.986, test=0.622) total time=   5.1s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.986, test=0.737) total time=   2.3s
# [CV 5/5] END learning_rate=0.023403473193207163, max_depth=70, n_estimators=200;, score=(train=0.982, test=0.742) total time=   4.7s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.587) total time=   3.4s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.987, test=0.587) total time=   2.2s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.993, test=0.638) total time=   2.2s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.990, test=0.585) total time=   2.4s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.597) total time=   4.0s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.652) total time=   3.5s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.748) total time=   3.7s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.638) total time=   4.5s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.992, test=0.646) total time=   2.0s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.986, test=0.737) total time=   2.5s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.998, test=0.587) total time=   1.6s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.996, test=0.608) total time=   1.8s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.996, test=0.597) total time=   3.6s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.998, test=0.587) total time=   4.0s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.995, test=0.652) total time=   3.5s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.638) total time=   4.1s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.995, test=0.662) total time=   1.7s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.997, test=0.630) total time=   2.0s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.996, test=0.748) total time=   3.6s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.996, test=0.724) total time=   2.0s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.998, test=0.587) total time=   1.6s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.996, test=0.608) total time=   1.7s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.597) total time=   2.7s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.605) total time=   2.8s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.594) total time=   3.4s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.997, test=0.630) total time=   1.8s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.713) total time=   2.8s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.657) total time=   3.2s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.995, test=0.662) total time=   1.8s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.996, test=0.724) total time=   1.8s
# [CV 1/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=(train=0.998, test=0.587) total time=   1.6s
# [CV 2/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=(train=0.996, test=0.590) total time=   1.4s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=200;, score=(train=0.996, test=0.597) total time=   2.6s
# [CV 3/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=(train=0.997, test=0.618) total time=   1.4s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=200;, score=(train=0.998, test=0.594) total time=   3.2s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.657) total time=   2.8s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=200;, score=(train=0.998, test=0.713) total time=   2.8s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.605) total time=   3.4s
# [CV 4/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=(train=0.997, test=0.642) total time=   1.7s
# [CV 5/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=(train=0.996, test=0.716) total time=   1.7s
# [CV 1/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.609) total time=   2.0s
# [CV 2/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.590) total time=   2.5s
# [CV 1/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=(train=0.998, test=0.587) total time=   1.7s
# [CV 4/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.628) total time=   2.4s
# [CV 5/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.735) total time=   2.2s
# [CV 2/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=(train=0.996, test=0.590) total time=   1.8s
# [CV 3/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.610) total time=   2.9s
# [CV 4/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=(train=0.997, test=0.642) total time=   1.3s
# [CV 3/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=(train=0.997, test=0.618) total time=   1.9s
# [CV 5/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=(train=0.996, test=0.716) total time=   1.5s
# [CV 1/5] END learning_rate=0.3, max_depth=70, n_estimators=200;, score=(train=0.998, test=0.609) total time=   2.0s
# [CV 2/5] END learning_rate=0.3, max_depth=70, n_estimators=200;, score=(train=0.996, test=0.590) total time=   1.9s
# [CV 3/5] END learning_rate=0.3, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.610) total time=   1.9s
# [CV 5/5] END learning_rate=0.3, max_depth=70, n_estimators=200;, score=(train=0.998, test=0.735) total time=   1.7s
# [CV 4/5] END learning_rate=0.3, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.628) total time=   1.9s
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 2535
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 5/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.698) total time=   7.5s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.990, test=0.631) total time=   7.7s
# [CV 4/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.687) total time=   8.8s
# [CV 3/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.627) total time=   9.1s
# [CV 1/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.998, test=0.629) total time=   9.4s
# [CV 2/5] END learning_rate=0.3, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.568) total time=   9.6s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.991, test=0.601) total time=  10.5s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.993, test=0.645) total time=  10.9s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.994, test=0.682) total time=   9.1s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=100;, score=(train=0.991, test=0.697) total time=   9.9s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.997, test=0.670) total time=  10.1s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.994, test=0.660) total time=  13.0s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.991, test=0.640) total time=  12.5s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.991, test=0.611) total time=  14.1s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.993, test=0.672) total time=  13.6s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.995, test=0.624) total time=   8.2s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.995, test=0.582) total time=   9.4s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.993, test=0.695) total time=  15.7s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.996, test=0.685) total time=   9.1s
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.995, test=0.616) total time=   7.9s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.997, test=0.641) total time=   9.3s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.995, test=0.580) total time=   8.1s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.995, test=0.698) total time=  10.4s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.996, test=0.682) total time=   8.5s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=50, n_estimators=100;, score=(train=0.995, test=0.690) total time=   8.9s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.997, test=0.650) total time=  18.2s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.590) total time=  18.3s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.626) total time=  17.8s
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.997, test=0.662) total time=  17.5s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.996, test=0.695) total time=  19.4s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.995, test=0.596) total time=  16.4s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=50, n_estimators=200;, score=(train=0.995, test=0.697) total time=  20.6s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.995, test=0.620) total time=  17.5s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.996, test=0.693) total time=  11.4s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.995, test=0.697) total time=   9.9s
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 7605
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 3/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.992, test=0.628) total time=  37.4s
# [CV 2/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.989, test=0.548) total time=  39.8s
# [CV 1/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.990, test=0.661) total time=  40.7s
# [CV 4/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.990, test=0.645) total time=  40.9s
# [CV 5/5] END learning_rate=0.1281861019188702, max_depth=70, n_estimators=100;, score=(train=0.989, test=0.706) total time=  43.0s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.988, test=0.544) total time= 1.3min
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.988, test=0.641) total time= 1.3min
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.991, test=0.625) total time= 1.3min
# [CV 1/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.984, test=0.645) total time=  41.3s
# [CV 2/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.983, test=0.536) total time=  41.8s
# [CV 3/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.983, test=0.630) total time=  40.2s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.984, test=0.644) total time=  23.1s
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.988, test=0.707) total time= 1.0min
# [CV 5/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=100;, score=(train=0.983, test=0.699) total time=  23.5s
# [CV 4/5] END learning_rate=0.05477225575051662, max_depth=70, n_estimators=200;, score=(train=0.989, test=0.647) total time= 1.1min
# XGB best model {'learning_rate': 0.1281861019188702, 'max_depth': 70, 'n_estimators': 100} 0.6375589983682882

# %%
results = pd.DataFrame(xgb_selection.cv_results_).sort_values('rank_test_score')[0:5].T
results
# Out:
#                                                                      4  \
# mean_fit_time                                                35.286061
# std_fit_time                                                  0.815371
# mean_score_time                                               0.112969
# std_score_time                                                0.007692
# param_learning_rate                                                0.3
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.3, 'max_depth': 50, 'n_est...
# split0_test_score                                              0.67069
# split1_test_score                                             0.521441
# split2_test_score                                             0.612368
# split3_test_score                                             0.588946
# split4_test_score                                             0.721408
# mean_test_score                                               0.622971
# std_test_score                                                0.068623
# rank_test_score                                                      1
#
#                                                                      0  \
# mean_fit_time                                                39.326933
# std_fit_time                                                  1.520437
# mean_score_time                                               0.117994
# std_score_time                                                0.007352
# param_learning_rate                                                0.2
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.2, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.670659
# split1_test_score                                             0.518135
# split2_test_score                                             0.624813
# split3_test_score                                             0.578716
# split4_test_score                                             0.715543
# mean_test_score                                               0.621573
# std_test_score                                                0.068973
# rank_test_score                                                      2
#
#                                                                      1  \
# mean_fit_time                                                46.869601
# std_fit_time                                                  2.234828
# mean_score_time                                               0.187901
# std_score_time                                                0.045118
# param_learning_rate                                                0.2
# param_max_depth                                                     50
# param_n_estimators                                                 130
# params               {'learning_rate': 0.2, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.674658
# split1_test_score                                             0.503951
# split2_test_score                                             0.618401
# split3_test_score                                             0.574487
# split4_test_score                                             0.714919
# mean_test_score                                               0.617283
# std_test_score                                                0.074164
# rank_test_score                                                      3
#
#                                                                      5  \
# mean_fit_time                                                43.259378
# std_fit_time                                                  1.039958
# mean_score_time                                               0.157442
# std_score_time                                                0.006508
# param_learning_rate                                                0.3
# param_max_depth                                                     50
# param_n_estimators                                                 130
# params               {'learning_rate': 0.3, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.662609
# split1_test_score                                             0.503067
# split2_test_score                                             0.613636
# split3_test_score                                             0.584133
# split4_test_score                                             0.708824
# mean_test_score                                               0.614454
# std_test_score                                                0.070074
# rank_test_score                                                      4
#
#                                                                      8
# mean_fit_time                                                32.593399
# std_fit_time                                                  1.429727
# mean_score_time                                                 0.1134
# std_score_time                                                0.006727
# param_learning_rate                                                0.4
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.4, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.670679
# split1_test_score                                             0.496014
# split2_test_score                                             0.621988
# split3_test_score                                             0.568345
# split4_test_score                                             0.712188
# mean_test_score                                               0.613843
# std_test_score                                                0.076055
# rank_test_score                                                      5

# %%
# Out:
# ({'learning_rate': 0.3, 'max_depth': 50, 'n_estimators': 100},
#  0.6229705173357942)
