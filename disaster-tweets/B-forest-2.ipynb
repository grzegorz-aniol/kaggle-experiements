# %% [markdown]
# # Random forest & Boosted trees + location check hipotesis

# %% [markdown]
# In this notebook I'm going to verify the hypotesis that detailed (cleaned) locations i.e. country/state have correlation with target classification

# %%
import re
import string
import numpy as np
import pandas as pd
import scipy as sp
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import feature_extraction, ensemble, model_selection, pipeline, compose, preprocessing
import xgboost as xg
import validators as vld

# %%
df_train = pd.read_csv('./train_enriched.csv')
df_train.fillna({'keyword':"", 'country': "", 'state': "", 'city': "", 'location_phrase': ""}, inplace=True)
df_train.shape
# Out:
# (7613, 20)

# %%
df_train.sample(n=5)
# Out:
#         id      keyword  positive_factor            location        country  \
# 340    340   armageddon         0.119048                Kent
# 2060  2060         dead         0.233333         Afghanistan    Afghanistan
# 1741  1741    collision         0.743590          Sacramento  United States
# 1051  1051  body%20bags         0.024390     California, USA  United States
# 4703  4703    landslide         0.424242  The Circle of Life
#
#            state        city  missing_location  \
# 340                                          0
# 2060                                         0
# 1741  California  Sacramento                 0
# 1051  California                             0
# 4703                                         0
#
#                                                    text  \
# 340   Lee does comedy: ÛÏ@LeeJasper: Working class ...
# 2060  17 dead as Afghanistan aircraft crashes: An Af...
# 1741  North Sac Elkhorn Blvd / Walerga Rd **Trfc Col...
# 1051  Womens Handbags Cross Body Geometric Pattern S...
# 4703  So when you're caught in a landslide\nI'll be ...
#
#                                              clean_text  text_length  \
# 340   lee comedy ûïleejasper working class tory pre...           91
# 2060  dead afghanistan aircraft crash afghan militar...          117
# 1741  north sac elkhorn blvd  walerga rd trfc collis...           77
# 1051  woman handbag cross body geometric pattern sat...          124
# 4703        caught landslide ill rain give sunshine ill           95
#
#       upper_text_factor  tags_count  punct_factor  ann_count  urls_count  \
# 340            0.131868           1      0.054945          1           0
# 2060           0.051282           0      0.076923          0           1
# 1741           0.155844           0      0.142857          0           1
# 1051           0.169355           0      0.088710          0           2
# 4703           0.042105           0      0.031579          0           0
#
#       tokens_count  stop_words_factor  clean_tokens_factor  target
# 340             12              0.250             0.750000       0
# 2060            20              0.300             0.650000       1
# 1741            11              0.000             0.909091       1
# 1051            15              0.000             0.866667       0
# 4703            24              0.625             0.375000       0

# %% [markdown]
# ## Features selection

# %%
categorical_features = [
    'country',
    'state',
]
numerical_features = [
    'text_length', 
    'urls_count',
    'stop_words_factor',
    'clean_tokens_factor',
    'positive_factor'
]

vc_text = feature_extraction.text.TfidfVectorizer(max_features=2000)

transformer = compose.ColumnTransformer(transformers=[
    ('text_vector', vc_text, 'clean_text'),
    ('one_hot', preprocessing.OneHotEncoder(handle_unknown='ignore'), categorical_features),
    ('numerical', preprocessing.StandardScaler(), numerical_features)
], remainder='drop')

X_train = transformer.fit_transform(df_train)
print('X_train shape', X_train.shape)

Y_train = df_train['target']
# X_train.columns = X_train.columns.astype(str)

X_train.shape, Y_train.shape

X_test = transformer.transform(pd.read_csv('./test_enriched.csv', index_col='id'))
print('X_test shape', X_test.shape)
# Out:
# X_train shape (7613, 2172)
# X_test shape (3263, 2172)

# %%
vc_text.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 vc_text.get_feature_names_out()
#
# File ~/anaconda3/envs/ml-experiments/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1479, in CountVectorizer.get_feature_names_out(self, input_features)
#    1466 def get_feature_names_out(self, input_features=None):
#    1467     """Get output feature names for transformation.
#    1468
#    1469     Parameters
#    (...)
#    1477         Transformed feature names.
#    1478     """
# -> 1479     self._check_vocabulary()
#    1480     return np.asarray(
#    1481         [t for t, i in sorted(self.vocabulary_.items(), key=itemgetter(1))],
#    1482         dtype=object,
#    1483     )
#
# File ~/anaconda3/envs/ml-experiments/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:508, in _VectorizerMixin._check_vocabulary(self)
#     506     self._validate_vocabulary()
#     507     if not self.fixed_vocabulary_:
# --> 508         raise NotFittedError("Vocabulary not fitted or provided")
#     510 if len(self.vocabulary_) == 0:
#     511     raise ValueError("Vocabulary is empty")
#
# NotFittedError: Vocabulary not fitted or provided

# %% [markdown]
# ## Model selection

# %% [markdown]
# ### Random forest

# %%
params_rf = {
    'n_estimators': [100, 200],
    'max_depth': [100, None]
}
model_rf = ensemble.RandomForestClassifier(n_jobs=2)
grid_rf = model_selection.GridSearchCV(model_rf, params_rf, cv=5, n_jobs=2, scoring='f1', verbose=3)
grid_rf.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 2/5] END ...max_depth=100, n_estimators=100;, score=0.610 total time=   1.4s
# [CV 1/5] END ...max_depth=100, n_estimators=100;, score=0.668 total time=   1.4s
# [CV 3/5] END ...max_depth=100, n_estimators=100;, score=0.679 total time=   1.3s
# [CV 4/5] END ...max_depth=100, n_estimators=100;, score=0.664 total time=   1.4s
# [CV 5/5] END ...max_depth=100, n_estimators=100;, score=0.743 total time=   1.8s
# [CV 1/5] END ...max_depth=100, n_estimators=200;, score=0.664 total time=   6.2s
# [CV 2/5] END ...max_depth=100, n_estimators=200;, score=0.609 total time=   8.7s
# [CV 3/5] END ...max_depth=100, n_estimators=200;, score=0.685 total time=   8.9s
# [CV 4/5] END ...max_depth=100, n_estimators=200;, score=0.666 total time=   9.9s
# [CV 5/5] END ...max_depth=100, n_estimators=200;, score=0.734 total time=  10.0s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.654 total time=   5.5s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.578 total time=   6.6s
# [CV 3/5] END ..max_depth=None, n_estimators=100;, score=0.671 total time=   6.5s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.656 total time=   5.0s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.746 total time=   4.8s
# [CV 1/5] END ..max_depth=None, n_estimators=200;, score=0.666 total time=   9.2s
# [CV 2/5] END ..max_depth=None, n_estimators=200;, score=0.606 total time=   9.1s
# [CV 3/5] END ..max_depth=None, n_estimators=200;, score=0.679 total time=   9.9s
# [CV 4/5] END ..max_depth=None, n_estimators=200;, score=0.657 total time=   9.8s
# [CV 5/5] END ..max_depth=None, n_estimators=200;, score=0.736 total time=   6.0s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=2), n_jobs=2,
#              param_grid={'max_depth': [100, None], 'n_estimators': [100, 200]},
#              scoring='f1', verbose=3)

# %%
grid_rf.best_params_, grid_rf.best_score_
# Out:
# ({'max_depth': 100, 'n_estimators': 100}, 0.6728790564309495)

# %%
np.sum(grid_rf.best_estimator_.feature_importances_ > 0.001)
# Out:
# 142

# %%
Y_predict = grid_rf.best_estimator_.predict(X_train)
df_wrong_predictions = pd.DataFrame({'target': Y_train.to_numpy(), 'predict': Y_predict, 'keyword': df_train['keyword'], 'location': df_train['location'], 'text': df_train['text']}).query('target != predict')

# %%
with pd.option_context('display.max_colwidth', 200):
    print(df_wrong_predictions.query('target==1').sample(n=10))
# Out:
#       target  predict     keyword                    location  \
# 7390       1        0   windstorm                         NaN
# 2965       1        0    drowning                         NaN
# 2040       1        0      danger            Atlanta Georgia
# 5984       1        0     screams  xiumin's nonexistent solos
# 7396       1        0   windstorm                 Webster, TX
# 2686       1        0  detonation                         NaN
# 4182       1        0      hazard                 Alameda, CA
# 3924       1        0       flood                    New York
# 5943       1        0    screamed    livin in a plastic world
# 4232       1        0   hazardous                         NaN
#
#                                                                                                                                              text
# 7390                                                                      @blakeshelton DON'T be a FART ??in a WINDSTORM.FOLLOW ME ALREADY. JEEZ.
# 2965                                                                                        'Drowning' - Acrylic 08.05.15 https://t.co/X17fUBQBGG
# 2040                      @bluebirddenver #FETTILOOTCH IS #SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM \nhttps://t.co/moLL5vd8yD
# 5984                                                                                           //screams in the distance// http://t.co/Cfe9HUQN0h
# 7396     TWIA board approves 5 percent rate hike: The Texas Windstorm Insurance Association (TWIA) Board of Directors v... http://t.co/TWPl0NL8cx
# 2686                                         Ignition Knock (Detonation) Sensor-Senso Standard KS94 http://t.co/IhphZCkm41 http://t.co/wuICdTTUhf
# 4182                                                                 Choking Hazard Prompts Recall Of Kraft Cheese Singles http://t.co/nJLqRqcnL9
# 3924  2pcs 18W CREE Led Work Light  Offroad Lamp Car Truck Boat Mining 4WD FLOOD BEAM - Full reaÛ_ http://t.co/ApWXS5Mm44 http://t.co/DS76loZLSu
# 5943                                                                                        I JUST SCREAMED @toddyrockstar http://t.co/JDtPirnm76
# 4232                                                                                          Caution: breathing may be hazardous to your health.

# %% [markdown]
# #### Generate output

# %%
Y_test_predict = grid_rf.best_estimator_.predict(X_test)

df_example = pd.read_csv('./sample_submission.csv')
df_example['target'] = Y_test_predict

df_example.to_csv('./b-forest-2-submission.csv', index=False)

# %% [markdown]
# ### Boosted trees

# %%
params_xgb = {
    'learning_rate': [0.2, 0.3, 0.4],
    'n_estimators': [100, 130],
    'max_depth': [50, 70]
}
model_xgb = xg.XGBClassifier()
grid_xgb = model_selection.GridSearchCV(model_xgb, params_xgb, cv=5, n_jobs=-1, scoring='f1', verbose=3)
grid_xgb.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 4/5] END learning_rate=0.2, max_depth=50, n_estimators=100;, score=0.579 total time=  36.5s
# [CV 3/5] END learning_rate=0.2, max_depth=50, n_estimators=100;, score=0.625 total time=  39.6s
# [CV 1/5] END learning_rate=0.2, max_depth=50, n_estimators=100;, score=0.671 total time=  40.1s
# [CV 5/5] END learning_rate=0.2, max_depth=50, n_estimators=100;, score=0.716 total time=  40.4s
# [CV 2/5] END learning_rate=0.2, max_depth=50, n_estimators=100;, score=0.518 total time=  40.7s
# [CV 2/5] END learning_rate=0.2, max_depth=50, n_estimators=130;, score=0.504 total time=  43.0s
# [CV 1/5] END learning_rate=0.2, max_depth=50, n_estimators=130;, score=0.675 total time=  49.0s
# [CV 3/5] END learning_rate=0.2, max_depth=50, n_estimators=130;, score=0.618 total time=  49.3s
# [CV 4/5] END learning_rate=0.2, max_depth=50, n_estimators=130;, score=0.574 total time=  47.1s
# [CV 5/5] END learning_rate=0.2, max_depth=50, n_estimators=130;, score=0.715 total time=  46.9s
# [CV 3/5] END learning_rate=0.2, max_depth=70, n_estimators=100;, score=0.607 total time=  47.8s
# [CV 2/5] END learning_rate=0.2, max_depth=70, n_estimators=100;, score=0.471 total time=  50.9s
# [CV 1/5] END learning_rate=0.2, max_depth=70, n_estimators=100;, score=0.654 total time=  54.1s
# [CV 4/5] END learning_rate=0.2, max_depth=70, n_estimators=100;, score=0.570 total time=  53.1s
# [CV 5/5] END learning_rate=0.2, max_depth=70, n_estimators=100;, score=0.708 total time=  55.1s
# [CV 1/5] END learning_rate=0.2, max_depth=70, n_estimators=130;, score=0.649 total time= 1.1min
# [CV 1/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=0.671 total time=  35.9s
# [CV 2/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=0.521 total time=  36.7s
# [CV 3/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=0.612 total time=  34.3s
# [CV 2/5] END learning_rate=0.2, max_depth=70, n_estimators=130;, score=0.468 total time=  59.5s
# [CV 4/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=0.589 total time=  35.2s
# [CV 3/5] END learning_rate=0.2, max_depth=70, n_estimators=130;, score=0.606 total time= 1.0min
# [CV 5/5] END learning_rate=0.2, max_depth=70, n_estimators=130;, score=0.696 total time= 1.0min
# [CV 4/5] END learning_rate=0.2, max_depth=70, n_estimators=130;, score=0.569 total time= 1.1min
# [CV 5/5] END learning_rate=0.3, max_depth=50, n_estimators=100;, score=0.721 total time=  34.9s
# [CV 1/5] END learning_rate=0.3, max_depth=50, n_estimators=130;, score=0.663 total time=  43.4s
# [CV 2/5] END learning_rate=0.3, max_depth=50, n_estimators=130;, score=0.503 total time=  41.7s
# [CV 3/5] END learning_rate=0.3, max_depth=50, n_estimators=130;, score=0.614 total time=  43.0s
# [CV 4/5] END learning_rate=0.3, max_depth=50, n_estimators=130;, score=0.584 total time=  44.4s
# [CV 5/5] END learning_rate=0.3, max_depth=50, n_estimators=130;, score=0.709 total time=  44.5s
# [CV 1/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=0.655 total time=  46.8s
# [CV 2/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=0.478 total time=  49.5s
# [CV 3/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=0.603 total time=  46.2s
# [CV 5/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=0.702 total time=  43.3s
# [CV 4/5] END learning_rate=0.3, max_depth=70, n_estimators=100;, score=0.594 total time=  47.2s
# [CV 1/5] END learning_rate=0.3, max_depth=70, n_estimators=130;, score=0.654 total time=  56.8s
# [CV 1/5] END learning_rate=0.4, max_depth=50, n_estimators=100;, score=0.671 total time=  34.1s
# [CV 3/5] END learning_rate=0.3, max_depth=70, n_estimators=130;, score=0.600 total time=  55.3s
# [CV 2/5] END learning_rate=0.3, max_depth=70, n_estimators=130;, score=0.465 total time=  57.5s
# [CV 3/5] END learning_rate=0.4, max_depth=50, n_estimators=100;, score=0.622 total time=  31.4s
# [CV 2/5] END learning_rate=0.4, max_depth=50, n_estimators=100;, score=0.496 total time=  32.3s
# [CV 4/5] END learning_rate=0.3, max_depth=70, n_estimators=130;, score=0.589 total time=  58.6s
# [CV 5/5] END learning_rate=0.3, max_depth=70, n_estimators=130;, score=0.694 total time=  59.5s
# [CV 5/5] END learning_rate=0.4, max_depth=50, n_estimators=100;, score=0.712 total time=  31.0s
# [CV 4/5] END learning_rate=0.4, max_depth=50, n_estimators=100;, score=0.568 total time=  34.6s
# [CV 1/5] END learning_rate=0.4, max_depth=50, n_estimators=130;, score=0.661 total time=  38.9s
# [CV 2/5] END learning_rate=0.4, max_depth=50, n_estimators=130;, score=0.493 total time=  39.4s
# [CV 4/5] END learning_rate=0.4, max_depth=50, n_estimators=130;, score=0.576 total time=  39.3s
# [CV 3/5] END learning_rate=0.4, max_depth=50, n_estimators=130;, score=0.624 total time=  42.6s
# [CV 5/5] END learning_rate=0.4, max_depth=50, n_estimators=130;, score=0.705 total time=  40.5s
# [CV 1/5] END learning_rate=0.4, max_depth=70, n_estimators=100;, score=0.643 total time=  42.8s
# [CV 2/5] END learning_rate=0.4, max_depth=70, n_estimators=100;, score=0.465 total time=  40.1s
# [CV 3/5] END learning_rate=0.4, max_depth=70, n_estimators=100;, score=0.612 total time=  43.9s
# [CV 4/5] END learning_rate=0.4, max_depth=70, n_estimators=100;, score=0.587 total time=  46.3s
# [CV 5/5] END learning_rate=0.4, max_depth=70, n_estimators=100;, score=0.682 total time=  44.8s
# [CV 1/5] END learning_rate=0.4, max_depth=70, n_estimators=130;, score=0.637 total time=  48.3s
# [CV 2/5] END learning_rate=0.4, max_depth=70, n_estimators=130;, score=0.469 total time=  46.7s
# [CV 3/5] END learning_rate=0.4, max_depth=70, n_estimators=130;, score=0.616 total time=  48.1s
# [CV 4/5] END learning_rate=0.4, max_depth=70, n_estimators=130;, score=0.581 total time=  44.4s
# [CV 5/5] END learning_rate=0.4, max_depth=70, n_estimators=130;, score=0.688 total time=  35.3s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.2, 0.3, 0.4],
#                          'max_depth': [50, 70], 'n_estimators': [100, 130]},
#              scoring='f1', verbose=3)

# %%
results = pd.DataFrame(grid_xgb.cv_results_).sort_values('rank_test_score')[0:5].T
results
# Out:
#                                                                      4  \
# mean_fit_time                                                35.286061
# std_fit_time                                                  0.815371
# mean_score_time                                               0.112969
# std_score_time                                                0.007692
# param_learning_rate                                                0.3
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.3, 'max_depth': 50, 'n_est...
# split0_test_score                                              0.67069
# split1_test_score                                             0.521441
# split2_test_score                                             0.612368
# split3_test_score                                             0.588946
# split4_test_score                                             0.721408
# mean_test_score                                               0.622971
# std_test_score                                                0.068623
# rank_test_score                                                      1
#
#                                                                      0  \
# mean_fit_time                                                39.326933
# std_fit_time                                                  1.520437
# mean_score_time                                               0.117994
# std_score_time                                                0.007352
# param_learning_rate                                                0.2
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.2, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.670659
# split1_test_score                                             0.518135
# split2_test_score                                             0.624813
# split3_test_score                                             0.578716
# split4_test_score                                             0.715543
# mean_test_score                                               0.621573
# std_test_score                                                0.068973
# rank_test_score                                                      2
#
#                                                                      1  \
# mean_fit_time                                                46.869601
# std_fit_time                                                  2.234828
# mean_score_time                                               0.187901
# std_score_time                                                0.045118
# param_learning_rate                                                0.2
# param_max_depth                                                     50
# param_n_estimators                                                 130
# params               {'learning_rate': 0.2, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.674658
# split1_test_score                                             0.503951
# split2_test_score                                             0.618401
# split3_test_score                                             0.574487
# split4_test_score                                             0.714919
# mean_test_score                                               0.617283
# std_test_score                                                0.074164
# rank_test_score                                                      3
#
#                                                                      5  \
# mean_fit_time                                                43.259378
# std_fit_time                                                  1.039958
# mean_score_time                                               0.157442
# std_score_time                                                0.006508
# param_learning_rate                                                0.3
# param_max_depth                                                     50
# param_n_estimators                                                 130
# params               {'learning_rate': 0.3, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.662609
# split1_test_score                                             0.503067
# split2_test_score                                             0.613636
# split3_test_score                                             0.584133
# split4_test_score                                             0.708824
# mean_test_score                                               0.614454
# std_test_score                                                0.070074
# rank_test_score                                                      4
#
#                                                                      8
# mean_fit_time                                                32.593399
# std_fit_time                                                  1.429727
# mean_score_time                                                 0.1134
# std_score_time                                                0.006727
# param_learning_rate                                                0.4
# param_max_depth                                                     50
# param_n_estimators                                                 100
# params               {'learning_rate': 0.4, 'max_depth': 50, 'n_est...
# split0_test_score                                             0.670679
# split1_test_score                                             0.496014
# split2_test_score                                             0.621988
# split3_test_score                                             0.568345
# split4_test_score                                             0.712188
# mean_test_score                                               0.613843
# std_test_score                                                0.076055
# rank_test_score                                                      5

# %%
grid_xgb.best_params_, grid_xgb.best_score_
# Out:
# ({'learning_rate': 0.3, 'max_depth': 50, 'n_estimators': 100},
#  0.6229705173357942)
