# %%
# %pip install pipenv
# %pip install scikit-learn
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install tensorflow
# %pip install xgboost
# %pip install ipympl
# %matplotlib widget

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, FunctionTransformer, PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
train_dataset = pd.read_csv('train.csv')

# %%
X_all = train_dataset.iloc[:,:-1]
Y_all = train_dataset.iloc[:,-1]
X_train, X_validate, Y_train, Y_validate = train_test_split(X_all, Y_all, test_size=0.2)
print(X_train.shape, Y_train.shape, X_validate.shape, Y_validate.shape)
# Out:
# (1168, 80) (1168,) (292, 80) (292,)

# %%
def check_model(X_train, Y_train, X_validate, Y_validate, model, preprocessor):
    print(X_train.shape, Y_train.shape)
    preprocessor.fit(X_train)
    X_train_scaled = preprocessor.transform(X_train)
    print('X_train_scaled shape', X_train_scaled.shape)
    model.fit(X_train_scaled, Y_train)
    Y_train_predict = model.predict(X_train_scaled)
    train_r2score = r2_score(Y_train, Y_train_predict)
    print(f'Train R2={train_r2score:.3f}')

    X_validate_scaled = preprocessor.transform(X_validate)
    Y_validate_predict = model.predict(X_validate_scaled)
    validate_r2score = r2_score(Y_validate, Y_validate_predict)
    print(f'Validate R2={validate_r2score:.3f}')

    return validate_r2score

# %%
def build_preprocessor():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), ['LotArea', 'GrLivArea', 'OverallQual', 'YearBuilt'])
        ])
    )

def build_model():
    model = LinearRegression()
    return model

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 4)
# Train R2=0.747
# Validate R2=0.751

# %%
def build_preprocessor_2():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), 
            ['LotArea', 'GrLivArea', 'OverallQual', 'YearBuilt', 'GarageArea', 'Fireplaces']
            )
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_2())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 6)
# Train R2=0.761
# Validate R2=0.782

# %%
def build_preprocessor_3():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), ['OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea']),
           ('numeric_log', FunctionTransformer(lambda x: np.log(x+0.001)), ['LotArea', 'GrLivArea'])
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_3())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 6)
# Train R2=0.753
# Validate R2=0.773
# 0.7725482285776857

# %%
selected_numerical_features = [
    'OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea',
    'LotArea', 'GrLivArea',
    'YearRemodAdd', 'TotRmsAbvGrd',
    'WoodDeckSF', 
]

def build_preprocessor_3a():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), selected_numerical_features),
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_3a())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 9)
# Train R2=0.766
# Validate R2=0.798
# 0.7980387649173375

# %%
print('selected_numerical_features',selected_numerical_features)
print('one_hot_features', one_hot_features)
print('ordinal_features', ordinal_features)
# Out:
# selected_numerical_features ['OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea', 'LotArea', 'GrLivArea', 'YearRemodAdd', 'TotRmsAbvGrd', 'WoodDeckSF']
# one_hot_features ['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'GarageFinish', 'SaleType']
# ordinal_features ['ExterQual', 'ExterCond']

# %% [markdown]
# ## Try with scaling output

# %%
def build_preprocessor_5():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), selected_numerical_features),
        ])
    )

check_model(X_train, np.log(Y_train), X_validate, np.log(Y_validate), build_model(), build_preprocessor_5())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 9)
# Train R2=0.830
# Validate R2=0.814
# 0.8138326612804762

# %% [markdown]
# ## Enhance with one hot encoded features

# %%
one_hot_features = [
'MSZoning',
'LotShape',
'LandContour',
'LotConfig',
'LandSlope',
'Neighborhood',
'BldgType',
'HouseStyle',
# 'RoofStyle',
# 'Exterior1st',
# 'Exterior2nd',
# 'Foundation',
# 'CentralAir',
# 'Electrical',
# 'GarageType',
'GarageFinish',
'SaleType',
# 'SaleCondition',
# 'RoofMatl' #Missing ['ClyTile', 'Metal'] in train data
# 'BldgType'
]

def build_preprocessor_with_onehot_1():
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', StandardScaler(), selected_numerical_features),
           ('one_hot', OneHotEncoder(), one_hot_features)
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_with_onehot_1())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 81)
# Train R2=0.843
# Validate R2=0.834
# 0.8341396345955728

# %% [markdown]
# ## Enhance with ordinal features

# %%
ordinal_values_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
ordinal_features = [
    'ExterQual',
    'ExterCond',
    # 'HeatingQC',
    # 'KitchenQual'
]
ordinal_value_per_feature = len(ordinal_features)*[ordinal_values_order]

def build_preprocessor_with_ordinal():
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler()
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
                                      encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder()
    )
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_with_ordinal())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 82)
# Train R2=0.844
# Validate R2=0.842
# 0.8421180857827473

# %% [markdown]
# ### Test with MasVnrArea

# %%
def build_preprocessor_with_masvnrarea():
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler()
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
                                      encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder()
    )
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    )

check_model(X_train, Y_train, X_validate, Y_validate, build_model(), build_preprocessor_with_masvnrarea())
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 83)
# Train R2=0.845
# Validate R2=0.847
# 0.8468366392200409

# %% [markdown]
# ## Check model with polynomials

# %%
def build_preprocessor_4(degree):
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler(),
        PolynomialFeatures(degree=degree, include_bias=False),
        StandardScaler(with_mean=False)
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
                                      encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder()
    )
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    )

def model_2(alpha):
    return Ridge(alpha=alpha)

best_params = (None, None)
best_result = None

for degree in range(2, 4):
    alpha = 3
    print(f'Degree={degree}, alpha={alpha}')
    preprocessor = build_preprocessor_4(degree)
    model = model_2(alpha)
    score = check_model(X_train, Y_train, X_validate, Y_validate, model, preprocessor)
    if not best_result or score > best_result:
        best_result = score
        best_params = (degree, alpha)
    print('---')

all_alphas = [1.0, 3.0, 10.0, 30.0, 100.0]
for alpha in all_alphas:
    degree = 2
    print(f'Degree={degree}, alpha={alpha}')
    preprocessor = build_preprocessor_4(degree)
    model = model_2(alpha)
    score = check_model(X_train, Y_train, X_validate, Y_validate, model, preprocessor)
    if score > best_result:
        best_result = score
        best_params = (degree, alpha)
    print('---')

print(f'The best score: {best_result} for degree={best_params[0]}, alpha={best_params[1]}')
# Out:
# Degree=2, alpha=3
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.896
# Validate R2=0.872
# ---
# Degree=3, alpha=3
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 293)
# Train R2=0.937
# Validate R2=0.770
# ---
# Degree=2, alpha=1.0
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.897
# Validate R2=0.865
# ---
# Degree=2, alpha=3.0
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.896
# Validate R2=0.872
# ---
# Degree=2, alpha=10.0
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.893
# Validate R2=0.882
# ---
# Degree=2, alpha=30.0
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.885
# Validate R2=0.887
# ---
# Degree=2, alpha=100.0
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.869
# Validate R2=0.881
# ---
# The best score: 0.8865171410578361 for degree=2, alpha=30.0

# %% [markdown]
# ## Checkpoint with the best model

# %%
def build_best_preprocessor(degree=2):
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler(),
        PolynomialFeatures(degree=degree, include_bias=False),
        StandardScaler(with_mean=False)
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
                                      encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder()
    )
    return make_pipeline(
        ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    )

def build_best_model(alpha=30.0):
    return Ridge(alpha=alpha)

# %%
best_preprocessor = build_best_preprocessor()
best_model = build_best_model()
check_model(X_train, Y_train, X_validate, Y_validate, best_model, best_preprocessor)
# Out:
# (1168, 80) (1168,)
# X_train_scaled shape (1168, 128)
# Train R2=0.885
# Validate R2=0.887
# 0.8865171410578361

# %% [markdown]
# ## F-statistic and p-values

# %%
# %precision 3
preprocessed_columns = best_preprocessor.get_feature_names_out()
from sklearn.feature_selection import f_regression
X_train_scaled = best_preprocessor.transform(X_train)
f_stat, p_values = f_regression(X_train_scaled,Y_train.to_numpy().reshape(1,-1)[0])
df_stat = pd.DataFrame(data={'fstat': f_stat, 'pvalue': p_values}, index=preprocessed_columns)
pd.set_option('display.max_rows', 200)
df_stat
# Out:
#                                            fstat         pvalue
# numeric1__OverallQual                1972.942506  5.366215e-253
# numeric1__YearBuilt                   424.541792   1.093365e-80
# numeric1__Fireplaces                  313.586905   2.496737e-62
# numeric1__GarageArea                  745.553512  2.566378e-127
# numeric1__LotArea                      85.208715   1.227376e-19
# numeric1__GrLivArea                  1213.865919  7.404326e-183
# numeric1__YearRemodAdd                380.730830   1.343460e-73
# numeric1__TotRmsAbvGrd                486.118067   2.515156e-90
# numeric1__WoodDeckSF                  136.485858   6.726762e-30
# numeric1__OverallQual^2               167.390811   7.105832e-36
# numeric1__OverallQual YearBuilt        46.277901   1.636365e-11
# numeric1__OverallQual Fireplaces       65.757985   1.280503e-15
# numeric1__OverallQual GarageArea      156.010420   1.084235e-33
# numeric1__OverallQual LotArea          26.477548   3.126108e-07
# numeric1__OverallQual GrLivArea       196.024207   2.771738e-41
# numeric1__OverallQual YearRemodAdd     39.763032   4.060935e-10
# numeric1__OverallQual TotRmsAbvGrd    151.410138   8.382509e-33
# numeric1__OverallQual WoodDeckSF       47.011678   1.141615e-11
# numeric1__YearBuilt^2                   0.659503   4.169011e-01
# numeric1__YearBuilt Fireplaces          0.009540   9.222087e-01
# numeric1__YearBuilt GarageArea         17.087446   3.825248e-05
# numeric1__YearBuilt LotArea             0.882486   3.477162e-01
# numeric1__YearBuilt GrLivArea          23.726017   1.263636e-06
# numeric1__YearBuilt YearRemodAdd        0.965030   3.261266e-01
# numeric1__YearBuilt TotRmsAbvGrd       29.946520   5.433068e-08
# numeric1__YearBuilt WoodDeckSF          3.921462   4.790817e-02
# numeric1__Fireplaces^2                 13.699663   2.245082e-04
# numeric1__Fireplaces GarageArea        23.685637   1.289888e-06
# numeric1__Fireplaces LotArea           11.308772   7.964610e-04
# numeric1__Fireplaces GrLivArea         75.333027   1.317477e-17
# numeric1__Fireplaces YearRemodAdd       5.823145   1.597010e-02
# numeric1__Fireplaces TotRmsAbvGrd      60.679470   1.477389e-14
# numeric1__Fireplaces WoodDeckSF         8.674882   3.290297e-03
# numeric1__GarageArea^2                 21.426194   4.089095e-06
# numeric1__GarageArea LotArea            8.996901   2.761772e-03
# numeric1__GarageArea GrLivArea         91.945711   5.180085e-21
# numeric1__GarageArea YearRemodAdd      39.947302   3.706884e-10
# numeric1__GarageArea TotRmsAbvGrd      92.502389   3.991428e-21
# numeric1__GarageArea WoodDeckSF        25.996408   3.988597e-07
# numeric1__LotArea^2                     8.928014   2.867060e-03
# numeric1__LotArea GrLivArea            26.530212   3.043884e-07
# numeric1__LotArea YearRemodAdd          0.069908   7.915179e-01
# numeric1__LotArea TotRmsAbvGrd         27.347616   2.013332e-07
# numeric1__LotArea WoodDeckSF            5.205171   2.269943e-02
# numeric1__GrLivArea^2                 116.985815   4.751441e-26
# numeric1__GrLivArea YearRemodAdd       43.226163   7.340597e-11
# numeric1__GrLivArea TotRmsAbvGrd      125.399383   1.019598e-27
# numeric1__GrLivArea WoodDeckSF         79.256618   2.044757e-18
# numeric1__YearRemodAdd^2               78.216376   3.348558e-18
# numeric1__YearRemodAdd TotRmsAbvGrd    38.608575   7.195504e-10
# numeric1__YearRemodAdd WoodDeckSF       0.345739   5.566488e-01
# numeric1__TotRmsAbvGrd^2               73.253908   3.545967e-17
# numeric1__TotRmsAbvGrd WoodDeckSF      29.818478   5.794390e-08
# numeric1__WoodDeckSF^2                 30.853656   3.444464e-08
# numeric2__MasVnrArea                  320.708836   1.505760e-63
# one_hot__MSZoning_C (all)               8.826429   3.029823e-03
# one_hot__MSZoning_FV                    8.972912   2.797983e-03
# one_hot__MSZoning_RH                    2.612449   1.062984e-01
# one_hot__MSZoning_RL                   67.306083   6.091478e-16
# one_hot__MSZoning_RM                  109.362675   1.580550e-24
# one_hot__LotShape_IR1                  60.049047   2.003262e-14
# one_hot__LotShape_IR2                  20.361756   7.058303e-06
# one_hot__LotShape_IR3                   1.604969   2.054535e-01
# one_hot__LotShape_Reg                  90.671044   9.414011e-21
# one_hot__LandContour_Bnk               11.374579   7.689971e-04
# one_hot__LandContour_HLS               20.038268   8.334634e-06
# one_hot__LandContour_Low                1.154895   2.827492e-01
# one_hot__LandContour_Lvl                1.230824   2.674756e-01
# one_hot__LotConfig_Corner               0.391185   5.317998e-01
# one_hot__LotConfig_CulDSac             27.051796   2.338015e-07
# one_hot__LotConfig_FR2                  0.930711   3.348784e-01
# one_hot__LotConfig_FR3                  0.353467   5.522726e-01
# one_hot__LotConfig_Inside              10.028983   1.580934e-03
# one_hot__LandSlope_Gtl                  1.893272   1.690975e-01
# one_hot__LandSlope_Mod                  1.912789   1.669185e-01
# one_hot__LandSlope_Sev                  0.068463   7.936344e-01
# one_hot__Neighborhood_Blmngtn           0.202836   6.525252e-01
# one_hot__Neighborhood_Blueste           0.633927   4.260807e-01
# one_hot__Neighborhood_BrDale           15.204172   1.019942e-04
# one_hot__Neighborhood_BrkSide          25.944483   4.094927e-07
# one_hot__Neighborhood_ClearCr           2.376663   1.234317e-01
# one_hot__Neighborhood_CollgCr           4.225224   4.004967e-02
# one_hot__Neighborhood_Crawfor           5.532157   1.883566e-02
# one_hot__Neighborhood_Edwards          34.667273   5.109422e-09
# one_hot__Neighborhood_Gilbert           1.280130   2.581076e-01
# one_hot__Neighborhood_IDOTRR           27.281908   2.081300e-07
# one_hot__Neighborhood_MeadowV          15.360729   9.398281e-05
# one_hot__Neighborhood_Mitchel           5.302625   2.146872e-02
# one_hot__Neighborhood_NAmes            45.105390   2.910910e-11
# one_hot__Neighborhood_NPkVill           1.421526   2.333950e-01
# one_hot__Neighborhood_NWAmes            0.354500   5.516921e-01
# one_hot__Neighborhood_NoRidge         150.913357   1.045903e-32
# one_hot__Neighborhood_NridgHt         228.799526   2.477605e-47
# one_hot__Neighborhood_OldTown          46.943551   1.180404e-11
# one_hot__Neighborhood_SWISU             2.995945   8.373773e-02
# one_hot__Neighborhood_Sawyer           18.618629   1.731775e-05
# one_hot__Neighborhood_SawyerW           1.123455   2.893953e-01
# one_hot__Neighborhood_Somerst          20.466400   6.689031e-06
# one_hot__Neighborhood_StoneBr          57.895480   5.677624e-14
# one_hot__Neighborhood_Timber           13.769598   2.163971e-04
# one_hot__Neighborhood_Veenker           4.708553   3.021431e-02
# one_hot__BldgType_1Fam                 22.687894   2.145243e-06
# one_hot__BldgType_2fmCon               11.127802   8.772179e-04
# one_hot__BldgType_Duplex               15.129175   1.060724e-04
# one_hot__BldgType_Twnhs                13.464592   2.540901e-04
# one_hot__BldgType_TwnhsE                0.002622   9.591697e-01
# one_hot__HouseStyle_1.5Fin             25.944261   4.095389e-07
# one_hot__HouseStyle_1.5Unf              7.376359   6.706372e-03
# one_hot__HouseStyle_1Story              4.765829   2.922896e-02
# one_hot__HouseStyle_2.5Fin              2.806224   9.416729e-02
# one_hot__HouseStyle_2.5Unf              0.881731   3.479225e-01
# one_hot__HouseStyle_2Story             64.223083   2.677903e-15
# one_hot__HouseStyle_SFoyer              9.622922   1.967808e-03
# one_hot__HouseStyle_SLvl                2.790009   9.512209e-02
# one_hot__GarageFinish_Fin             257.014136   2.007871e-52
# one_hot__GarageFinish_RFn              25.785073   4.439481e-07
# one_hot__GarageFinish_Unf             399.572976   1.134148e-76
# one_hot__SaleType_COD                   8.297907   4.041718e-03
# one_hot__SaleType_CWD                   0.417427   5.183509e-01
# one_hot__SaleType_Con                   2.156575   1.422305e-01
# one_hot__SaleType_ConLD                 1.011033   3.148642e-01
# one_hot__SaleType_ConLI                 0.732208   3.923441e-01
# one_hot__SaleType_ConLw                 1.675961   1.957184e-01
# one_hot__SaleType_New                 172.556568   7.360626e-37
# one_hot__SaleType_Oth                   1.813964   1.782952e-01
# one_hot__SaleType_WD                   82.530589   4.343255e-19
# ordinal__ExterQual                   1024.498173  7.617954e-162
# ordinal__ExterCond                      0.105548   7.453292e-01

# %% [markdown]
# ## Test dataset evaluation

# %%
X_test = pd.read_csv('test.csv')

# %%
tmp = X_test[selected_numerical_features + ordinal_features + one_hot_features]

tmp.isnull().any()
# Out:
# OverallQual     False
# YearBuilt       False
# Fireplaces      False
# GarageArea       True
# YearRemodAdd    False
# TotRmsAbvGrd    False
# WoodDeckSF      False
# ExterQual       False
# ExterCond       False
# MSZoning         True
# LotShape        False
# LandContour     False
# LotConfig       False
# LandSlope       False
# Neighborhood    False
# BldgType        False
# HouseStyle      False
# GarageFinish     True
# SaleType         True
# dtype: bool

# %%
the_best_model = m1
the_best_preprocessor = preprocessor_with_ordinal_1
X_test_scaled = the_best_preprocessor.transform(X_test)
Y_test_predict = the_best_model.predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[197], line 4
#       2 the_best_preprocessor = preprocessor_with_ordinal_1
#       3 X_test_scaled = the_best_preprocessor.transform(X_test)
# ----> 4 Y_test_predict = the_best_model.predict(X_test_scaled)
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/linear_model/_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/linear_model/_base.py:269, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
#     267     check_is_fitted(self)
# --> 269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 82 features, but LinearRegression is expecting 84 features as input.
