# %% [markdown]
# # House prediction model
# ## Simple solution with just few features, using deep learning with tensorflow

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
dataset = pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
selected_data = dataset[['LotArea', 'OverallQual', 'OverallCond', 'GrLivArea','SalePrice']]
selected_data.describe()
# Out:
#              LotArea  OverallQual  OverallCond    GrLivArea      SalePrice
# count    1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    10516.828082     6.099315     5.575342  1515.463699  180921.195890
# std      9981.264932     1.382997     1.112799   525.480383   79442.502883
# min      1300.000000     1.000000     1.000000   334.000000   34900.000000
# 25%      7553.500000     5.000000     5.000000  1129.500000  129975.000000
# 50%      9478.500000     6.000000     5.000000  1464.000000  163000.000000
# 75%     11601.500000     7.000000     6.000000  1776.750000  214000.000000
# max    215245.000000    10.000000     9.000000  5642.000000  755000.000000

# %% [markdown]
# ### Drop outliers

# %%
filtered1 = selected_data[selected_data['LotArea'] < 20000]

# %% [markdown]
# ### Prepare input and outputs

# %%
inputs = filtered1.iloc[:,:4]
inputs.head()
# Out:
#    LotArea  OverallQual  OverallCond  GrLivArea
# 0     8450            7            5       1710
# 1     9600            6            8       1262
# 2    11250            7            5       1786
# 3     9550            7            5       1717
# 4    14260            8            5       2198

# %%
targets = filtered1.iloc[:,4:]
targets.head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %% [markdown]
# ### Split data to training and test

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(inputs, targets)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1055, 4)
# (1055, 1)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# ((1055, 4), (352, 4))

# %% [markdown]
# ### Defining model

# %%
INPUT_SIZE = X_train_scaled.shape[1]
OUTPUT_SIZE = Y_train.shape[1]
HIDDEN_LAYER_SIZE = 300
BATCH_SIZE= 100
MAX_EPOCHS = 100
(INPUT_SIZE, OUTPUT_SIZE)
# Out:
# (4, 1)

# %%
def baseline_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(HIDDEN_LAYER_SIZE, input_shape=(INPUT_SIZE,), activation='relu'),
        tf.keras.layers.Dense(HIDDEN_LAYER_SIZE, activation='relu'),
        tf.keras.layers.Dense(OUTPUT_SIZE)
    ])
    #model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['root_mean_squared_error'])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ### Training

# %%
model = baseline_model()
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)
model.fit(X_train_scaled, Y_train, batch_size=BATCH_SIZE, epochs=MAX_EPOCHS, validation_split=0.1, 
          callbacks=[early_stopping],
          verbose=2)
# Out:
# Epoch 1/100
# 10/10 - 0s - loss: 38442954752.0000 - val_loss: 31380062208.0000 - 498ms/epoch - 50ms/step
# Epoch 2/100
# 10/10 - 0s - loss: 38441701376.0000 - val_loss: 31378724864.0000 - 32ms/epoch - 3ms/step
# Epoch 3/100
# 10/10 - 0s - loss: 38439563264.0000 - val_loss: 31376406528.0000 - 30ms/epoch - 3ms/step
# Epoch 4/100
# 10/10 - 0s - loss: 38435811328.0000 - val_loss: 31372591104.0000 - 28ms/epoch - 3ms/step
# Epoch 5/100
# 10/10 - 0s - loss: 38429618176.0000 - val_loss: 31366582272.0000 - 29ms/epoch - 3ms/step
# Epoch 6/100
# 10/10 - 0s - loss: 38420111360.0000 - val_loss: 31357548544.0000 - 28ms/epoch - 3ms/step
# Epoch 7/100
# 10/10 - 0s - loss: 38405730304.0000 - val_loss: 31344609280.0000 - 28ms/epoch - 3ms/step
# Epoch 8/100
# 10/10 - 0s - loss: 38385815552.0000 - val_loss: 31326697472.0000 - 28ms/epoch - 3ms/step
# Epoch 9/100
# 10/10 - 0s - loss: 38358724608.0000 - val_loss: 31302862848.0000 - 30ms/epoch - 3ms/step
# Epoch 10/100
# 10/10 - 0s - loss: 38322651136.0000 - val_loss: 31271968768.0000 - 29ms/epoch - 3ms/step
# Epoch 11/100
# 10/10 - 0s - loss: 38274859008.0000 - val_loss: 31233017856.0000 - 29ms/epoch - 3ms/step
# Epoch 12/100
# 10/10 - 0s - loss: 38217940992.0000 - val_loss: 31184101376.0000 - 27ms/epoch - 3ms/step
# Epoch 13/100
# 10/10 - 0s - loss: 38143352832.0000 - val_loss: 31125133312.0000 - 28ms/epoch - 3ms/step
# Epoch 14/100
# 10/10 - 0s - loss: 38055624704.0000 - val_loss: 31053395968.0000 - 31ms/epoch - 3ms/step
# Epoch 15/100
# 10/10 - 0s - loss: 37950185472.0000 - val_loss: 30968514560.0000 - 31ms/epoch - 3ms/step
# Epoch 16/100
# 10/10 - 0s - loss: 37826428928.0000 - val_loss: 30869667840.0000 - 28ms/epoch - 3ms/step
# Epoch 17/100
# 10/10 - 0s - loss: 37678993408.0000 - val_loss: 30756106240.0000 - 29ms/epoch - 3ms/step
# Epoch 18/100
# 10/10 - 0s - loss: 37512294400.0000 - val_loss: 30625757184.0000 - 29ms/epoch - 3ms/step
# Epoch 19/100
# 10/10 - 0s - loss: 37321273344.0000 - val_loss: 30478182400.0000 - 29ms/epoch - 3ms/step
# Epoch 20/100
# 10/10 - 0s - loss: 37109645312.0000 - val_loss: 30310438912.0000 - 27ms/epoch - 3ms/step
# Epoch 21/100
# 10/10 - 0s - loss: 36861005824.0000 - val_loss: 30127628288.0000 - 29ms/epoch - 3ms/step
# Epoch 22/100
# 10/10 - 0s - loss: 36598587392.0000 - val_loss: 29921818624.0000 - 28ms/epoch - 3ms/step
# Epoch 23/100
# 10/10 - 0s - loss: 36296159232.0000 - val_loss: 29698611200.0000 - 29ms/epoch - 3ms/step
# Epoch 24/100
# 10/10 - 0s - loss: 35971407872.0000 - val_loss: 29450172416.0000 - 28ms/epoch - 3ms/step
# Epoch 25/100
# 10/10 - 0s - loss: 35615801344.0000 - val_loss: 29175152640.0000 - 28ms/epoch - 3ms/step
# Epoch 26/100
# 10/10 - 0s - loss: 35222417408.0000 - val_loss: 28881707008.0000 - 29ms/epoch - 3ms/step
# Epoch 27/100
# 10/10 - 0s - loss: 34805465088.0000 - val_loss: 28566904832.0000 - 29ms/epoch - 3ms/step
# Epoch 28/100
# 10/10 - 0s - loss: 34359767040.0000 - val_loss: 28226084864.0000 - 28ms/epoch - 3ms/step
# Epoch 29/100
# 10/10 - 0s - loss: 33871294464.0000 - val_loss: 27864934400.0000 - 28ms/epoch - 3ms/step
# Epoch 30/100
# 10/10 - 0s - loss: 33350084608.0000 - val_loss: 27484188672.0000 - 29ms/epoch - 3ms/step
# Epoch 31/100
# 10/10 - 0s - loss: 32815728640.0000 - val_loss: 27070957568.0000 - 30ms/epoch - 3ms/step
# Epoch 32/100
# 10/10 - 0s - loss: 32223354880.0000 - val_loss: 26638444544.0000 - 29ms/epoch - 3ms/step
# Epoch 33/100
# 10/10 - 0s - loss: 31625388032.0000 - val_loss: 26175432704.0000 - 29ms/epoch - 3ms/step
# Epoch 34/100
# 10/10 - 0s - loss: 30982295552.0000 - val_loss: 25694773248.0000 - 28ms/epoch - 3ms/step
# Epoch 35/100
# 10/10 - 0s - loss: 30305259520.0000 - val_loss: 25196564480.0000 - 29ms/epoch - 3ms/step
# Epoch 36/100
# 10/10 - 0s - loss: 29601366016.0000 - val_loss: 24681050112.0000 - 29ms/epoch - 3ms/step
# Epoch 37/100
# 10/10 - 0s - loss: 28894656512.0000 - val_loss: 24134959104.0000 - 29ms/epoch - 3ms/step
# Epoch 38/100
# 10/10 - 0s - loss: 28131219456.0000 - val_loss: 23575441408.0000 - 29ms/epoch - 3ms/step
# Epoch 39/100
# 10/10 - 0s - loss: 27370747904.0000 - val_loss: 22986991616.0000 - 30ms/epoch - 3ms/step
# Epoch 40/100
# 10/10 - 0s - loss: 26549168128.0000 - val_loss: 22399514624.0000 - 31ms/epoch - 3ms/step
# Epoch 41/100
# 10/10 - 0s - loss: 25743388672.0000 - val_loss: 21792147456.0000 - 30ms/epoch - 3ms/step
# Epoch 42/100
# 10/10 - 0s - loss: 24906635264.0000 - val_loss: 21171140608.0000 - 29ms/epoch - 3ms/step
# Epoch 43/100
# 10/10 - 0s - loss: 24067280896.0000 - val_loss: 20533630976.0000 - 29ms/epoch - 3ms/step
# Epoch 44/100
# 10/10 - 0s - loss: 23207749632.0000 - val_loss: 19880249344.0000 - 28ms/epoch - 3ms/step
# Epoch 45/100
# 10/10 - 0s - loss: 22342703104.0000 - val_loss: 19221882880.0000 - 30ms/epoch - 3ms/step
# Epoch 46/100
# 10/10 - 0s - loss: 21460475904.0000 - val_loss: 18560135168.0000 - 29ms/epoch - 3ms/step
# Epoch 47/100
# 10/10 - 0s - loss: 20591192064.0000 - val_loss: 17885485056.0000 - 31ms/epoch - 3ms/step
# Epoch 48/100
# 10/10 - 0s - loss: 19700893696.0000 - val_loss: 17223036928.0000 - 28ms/epoch - 3ms/step
# Epoch 49/100
# 10/10 - 0s - loss: 18840596480.0000 - val_loss: 16553236480.0000 - 28ms/epoch - 3ms/step
# Epoch 50/100
# 10/10 - 0s - loss: 17977391104.0000 - val_loss: 15882656768.0000 - 29ms/epoch - 3ms/step
# Epoch 51/100
# 10/10 - 0s - loss: 17115127808.0000 - val_loss: 15228474368.0000 - 31ms/epoch - 3ms/step
# Epoch 52/100
# 10/10 - 0s - loss: 16290785280.0000 - val_loss: 14576109568.0000 - 31ms/epoch - 3ms/step
# Epoch 53/100
# 10/10 - 0s - loss: 15461774336.0000 - val_loss: 13933431808.0000 - 29ms/epoch - 3ms/step
# Epoch 54/100
# 10/10 - 0s - loss: 14671014912.0000 - val_loss: 13295956992.0000 - 29ms/epoch - 3ms/step
# Epoch 55/100
# 10/10 - 0s - loss: 13893658624.0000 - val_loss: 12678624256.0000 - 29ms/epoch - 3ms/step
# Epoch 56/100
# 10/10 - 0s - loss: 13140064256.0000 - val_loss: 12079993856.0000 - 28ms/epoch - 3ms/step
# Epoch 57/100
# 10/10 - 0s - loss: 12438073344.0000 - val_loss: 11484638208.0000 - 29ms/epoch - 3ms/step
# Epoch 58/100
# 10/10 - 0s - loss: 11722678272.0000 - val_loss: 10924491776.0000 - 27ms/epoch - 3ms/step
# Epoch 59/100
# 10/10 - 0s - loss: 11074999296.0000 - val_loss: 10377428992.0000 - 27ms/epoch - 3ms/step
# Epoch 60/100
# 10/10 - 0s - loss: 10439658496.0000 - val_loss: 9858406400.0000 - 28ms/epoch - 3ms/step
# Epoch 61/100
# 10/10 - 0s - loss: 9852408832.0000 - val_loss: 9357175808.0000 - 28ms/epoch - 3ms/step
# Epoch 62/100
# 10/10 - 0s - loss: 9292839936.0000 - val_loss: 8876874752.0000 - 27ms/epoch - 3ms/step
# Epoch 63/100
# 10/10 - 0s - loss: 8771872768.0000 - val_loss: 8415787008.0000 - 29ms/epoch - 3ms/step
# Epoch 64/100
# 10/10 - 0s - loss: 8282370048.0000 - val_loss: 7976367616.0000 - 29ms/epoch - 3ms/step
# Epoch 65/100
# 10/10 - 0s - loss: 7818523648.0000 - val_loss: 7563287552.0000 - 32ms/epoch - 3ms/step
# Epoch 66/100
# 10/10 - 0s - loss: 7392994304.0000 - val_loss: 7169334784.0000 - 28ms/epoch - 3ms/step
# Epoch 67/100
# 10/10 - 0s - loss: 7003069952.0000 - val_loss: 6794969088.0000 - 28ms/epoch - 3ms/step
# Epoch 68/100
# 10/10 - 0s - loss: 6627822080.0000 - val_loss: 6455600128.0000 - 28ms/epoch - 3ms/step
# Epoch 69/100
# 10/10 - 0s - loss: 6298621440.0000 - val_loss: 6132215296.0000 - 29ms/epoch - 3ms/step
# Epoch 70/100
# 10/10 - 0s - loss: 5993874944.0000 - val_loss: 5829642752.0000 - 27ms/epoch - 3ms/step
# Epoch 71/100
# 10/10 - 0s - loss: 5715680256.0000 - val_loss: 5544830464.0000 - 28ms/epoch - 3ms/step
# Epoch 72/100
# 10/10 - 0s - loss: 5461201920.0000 - val_loss: 5277763584.0000 - 28ms/epoch - 3ms/step
# Epoch 73/100
# 10/10 - 0s - loss: 5226162688.0000 - val_loss: 5032796672.0000 - 29ms/epoch - 3ms/step
# Epoch 74/100
# 10/10 - 0s - loss: 5012079104.0000 - val_loss: 4807008256.0000 - 28ms/epoch - 3ms/step
# Epoch 75/100
# 10/10 - 0s - loss: 4821840384.0000 - val_loss: 4590380544.0000 - 27ms/epoch - 3ms/step
# Epoch 76/100
# 10/10 - 0s - loss: 4641632768.0000 - val_loss: 4390531072.0000 - 29ms/epoch - 3ms/step
# Epoch 77/100
# 10/10 - 0s - loss: 4479519232.0000 - val_loss: 4201418240.0000 - 28ms/epoch - 3ms/step
# Epoch 78/100
# 10/10 - 0s - loss: 4331596800.0000 - val_loss: 4025958144.0000 - 28ms/epoch - 3ms/step
# Epoch 79/100
# 10/10 - 0s - loss: 4192259072.0000 - val_loss: 3869343488.0000 - 28ms/epoch - 3ms/step
# Epoch 80/100
# 10/10 - 0s - loss: 4067870464.0000 - val_loss: 3722317056.0000 - 30ms/epoch - 3ms/step
# Epoch 81/100
# 10/10 - 0s - loss: 3955075584.0000 - val_loss: 3583161856.0000 - 28ms/epoch - 3ms/step
# Epoch 82/100
# 10/10 - 0s - loss: 3847257856.0000 - val_loss: 3455460352.0000 - 27ms/epoch - 3ms/step
# Epoch 83/100
# 10/10 - 0s - loss: 3745942272.0000 - val_loss: 3337888256.0000 - 27ms/epoch - 3ms/step
# Epoch 84/100
# 10/10 - 0s - loss: 3657531136.0000 - val_loss: 3220503296.0000 - 29ms/epoch - 3ms/step
# Epoch 85/100
# 10/10 - 0s - loss: 3569925376.0000 - val_loss: 3118962688.0000 - 29ms/epoch - 3ms/step
# Epoch 86/100
# 10/10 - 0s - loss: 3487816960.0000 - val_loss: 3023263232.0000 - 29ms/epoch - 3ms/step
# Epoch 87/100
# 10/10 - 0s - loss: 3412479744.0000 - val_loss: 2931052544.0000 - 28ms/epoch - 3ms/step
# Epoch 88/100
# 10/10 - 0s - loss: 3340826880.0000 - val_loss: 2845893888.0000 - 29ms/epoch - 3ms/step
# Epoch 89/100
# 10/10 - 0s - loss: 3274717440.0000 - val_loss: 2761804544.0000 - 31ms/epoch - 3ms/step
# Epoch 90/100
# 10/10 - 0s - loss: 3208444928.0000 - val_loss: 2686768384.0000 - 31ms/epoch - 3ms/step
# Epoch 91/100
# 10/10 - 0s - loss: 3148600320.0000 - val_loss: 2616251136.0000 - 29ms/epoch - 3ms/step
# Epoch 92/100
# 10/10 - 0s - loss: 3091834112.0000 - val_loss: 2547230976.0000 - 29ms/epoch - 3ms/step
# Epoch 93/100
# 10/10 - 0s - loss: 3037011456.0000 - val_loss: 2484631808.0000 - 29ms/epoch - 3ms/step
# Epoch 94/100
# 10/10 - 0s - loss: 2985467648.0000 - val_loss: 2426057216.0000 - 29ms/epoch - 3ms/step
# Epoch 95/100
# 10/10 - 0s - loss: 2935898880.0000 - val_loss: 2371526400.0000 - 27ms/epoch - 3ms/step
# Epoch 96/100
# 10/10 - 0s - loss: 2888751872.0000 - val_loss: 2319373568.0000 - 27ms/epoch - 3ms/step
# Epoch 97/100
# 10/10 - 0s - loss: 2843424512.0000 - val_loss: 2269219328.0000 - 28ms/epoch - 3ms/step
# Epoch 98/100
# 10/10 - 0s - loss: 2800292608.0000 - val_loss: 2222685696.0000 - 28ms/epoch - 3ms/step
# Epoch 99/100
# 10/10 - 0s - loss: 2758935296.0000 - val_loss: 2179072512.0000 - 27ms/epoch - 3ms/step
# Epoch 100/100
# 10/10 - 0s - loss: 2719226880.0000 - val_loss: 2136789248.0000 - 27ms/epoch - 3ms/step

# %% [markdown]
# ### Model evaluation

# %%
# estimator.fit(X_train_scaled, Y_train)
Y_predicted = model.predict(X_train_scaled)
Y_predicted[Y_predicted < 1] = 1.0
Y_log_predicted = np.log(Y_predicted)
Y_log_train = np.log(Y_train)
# Out:
# 33/33 [==============================] - 0s 647us/step

# %%
rmse = root_mean_squared_error(Y_log_predicted, Y_log_train)
print('RMSE:', rmse)
# Out:
# RMSE: 0.3446343771145354

# %%
df_results = pd.DataFrame(data=np.column_stack((Y_train, Y_predicted)), columns=["Y_train", "Y_predicted"])
df_results.head()
# Out:
#     Y_train    Y_predicted
# 0  240000.0  209779.359375
# 1   97000.0  138057.796875
# 2  116000.0  127561.117188
# 3  109500.0  157830.515625
# 4  159000.0  100057.437500
