# %% [markdown]
# # House price prediction with deep learning model

# %%
# %pip install pipenv
# %pip install scikit-learn
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install tensorflow
# %pip install xgboost
# %pip install ipympl
# %matplotlib widget

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
# from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
# FILE_NAME='train.csv'
FILE_NAME='train_inliers.csv'
train_dataset = pd.read_csv(FILE_NAME)
train_dataset.head()
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0           0   1          60       RL         65.0     8450   Pave   NaN
# 1           1   2          20       RL         80.0     9600   Pave   NaN
# 2           2   3          60       RL         68.0    11250   Pave   NaN
# 3           3   4          70       RL         60.0     9550   Pave   NaN
# 4           4   5          60       RL         84.0    14260   Pave   NaN
#
#   LotShape LandContour  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0      Reg         Lvl  ...        0    NaN   NaN         NaN       0      2
# 1      Reg         Lvl  ...        0    NaN   NaN         NaN       0      5
# 2      IR1         Lvl  ...        0    NaN   NaN         NaN       0      9
# 3      IR1         Lvl  ...        0    NaN   NaN         NaN       0      2
# 4      IR1         Lvl  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold SaleType  SaleCondition  SalePrice
# 0   2008       WD         Normal     208500
# 1   2007       WD         Normal     181500
# 2   2008       WD         Normal     223500
# 3   2006       WD        Abnorml     140000
# 4   2008       WD         Normal     250000
#
# [5 rows x 82 columns]

# %%
X_all = train_dataset.iloc[:,:-1]
# Y_all = np.log(train_dataset.iloc[:,-1]).to_numpy()
# Y_all = Y_all.reshape(-1, 1)
Y_all = (train_dataset.iloc[:,-1]).to_numpy().reshape(-1,1)

print(X_all.shape, Y_all.shape)
# X_train, X_validate, Y_train, Y_validate = train_test_split(X_all, Y_all, test_size=0.2)
# print(X_train.shape, Y_train.shape, X_validate.shape, Y_validate.shape)
# Out:
# (1422, 81) (1422, 1)

# %% [markdown]
# ### Features selection

# %%
selected_numerical_features = [
    'OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea',
    'LotArea', 'GrLivArea',
    'YearRemodAdd', 'TotRmsAbvGrd',
    'WoodDeckSF', 
]

one_hot_features = [
'MSZoning',
'LotShape',
'LandContour',
'LotConfig',
'LandSlope',
'Neighborhood',
'BldgType',
'HouseStyle',
'GarageFinish',
'SaleType',

'RoofStyle',
'Exterior1st',
'Exterior2nd',
'Foundation',
'CentralAir',
'Electrical',
'GarageType',
'SaleCondition',
'BldgType'
# 'RoofMatl' #Missing ['ClyTile', 'Metal'] in train data
]

ordinal_values_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
ordinal_features = [
    'ExterQual',
    'ExterCond',
    'HeatingQC',
    'KitchenQual'
]
ordinal_value_per_feature = len(ordinal_features)*[ordinal_values_order]

# %% [markdown]
# ### Preprocessing data

# %%
def build_preprocessor(degree=2):
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler()
        # PolynomialFeatures(degree=degree, include_bias=False),
        # StandardScaler(with_mean=False)
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
            encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), 
        OneHotEncoder(sparse_output=False)
    )
    transformer = ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    return transformer

# %%
preprocessor = build_preprocessor()

# %%
X_train_scaled = preprocessor.fit_transform(X_all)

# %% [markdown]
# ### Model

# %%
INPUT_SIZE = X_train_scaled.shape[1]
OUTPUT_SIZE = 1
HIDDEN_LAYER_SIZE = 2048
BATCH_SIZE= 64
MAX_EPOCHS = 200

def baseline_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(HIDDEN_LAYER_SIZE, input_shape=(INPUT_SIZE,), activation='relu'),
        tf.keras.layers.Dense(HIDDEN_LAYER_SIZE/2, activation='relu'),
        tf.keras.layers.Dense(HIDDEN_LAYER_SIZE/4, activation='relu'),
        tf.keras.layers.Dense(OUTPUT_SIZE)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=tf.keras.metrics.RootMeanSquaredError())
    return model

# %% [markdown]
# ### Training

# %%
model = baseline_model()
early_stopping = tf.keras.callbacks.EarlyStopping(patience=5)
model.fit(X_train_scaled, Y_all, batch_size=BATCH_SIZE, epochs=MAX_EPOCHS, validation_split=0.2, 
          callbacks=[early_stopping],
          verbose=2)
Y_predict = model.predict(X_train_scaled)
rmse_score = root_mean_squared_error(np.log(Y_all+0.001), np.log(Y_predict+0.001))
# rmse_score = root_mean_squared_error(Y_all, Y_predict)
r2 = r2_score(Y_all, Y_predict)
print(f'rmse={rmse_score:.2f}, r2={r2:.2f}')
# Out:
# Epoch 1/200
# 18/18 - 1s - loss: 36333907968.0000 - root_mean_squared_error: 190614.5469 - val_loss: 35068727296.0000 - val_root_mean_squared_error: 187266.4531 - 749ms/epoch - 42ms/step
# Epoch 2/200
# 18/18 - 0s - loss: 32761722880.0000 - root_mean_squared_error: 181002.0000 - val_loss: 25216800768.0000 - val_root_mean_squared_error: 158797.9844 - 338ms/epoch - 19ms/step
# Epoch 3/200
# 18/18 - 0s - loss: 13096873984.0000 - root_mean_squared_error: 114441.5781 - val_loss: 1118121216.0000 - val_root_mean_squared_error: 33438.3203 - 335ms/epoch - 19ms/step
# Epoch 4/200
# 18/18 - 0s - loss: 1841664128.0000 - root_mean_squared_error: 42914.6133 - val_loss: 1048708096.0000 - val_root_mean_squared_error: 32383.7637 - 294ms/epoch - 16ms/step
# Epoch 5/200
# 18/18 - 0s - loss: 1072600128.0000 - root_mean_squared_error: 32750.5742 - val_loss: 940229440.0000 - val_root_mean_squared_error: 30663.1602 - 292ms/epoch - 16ms/step
# Epoch 6/200
# 18/18 - 0s - loss: 828900096.0000 - root_mean_squared_error: 28790.6250 - val_loss: 851486592.0000 - val_root_mean_squared_error: 29180.2441 - 302ms/epoch - 17ms/step
# Epoch 7/200
# 18/18 - 0s - loss: 754463872.0000 - root_mean_squared_error: 27467.5059 - val_loss: 808873152.0000 - val_root_mean_squared_error: 28440.6953 - 303ms/epoch - 17ms/step
# Epoch 8/200
# 18/18 - 0s - loss: 713566720.0000 - root_mean_squared_error: 26712.6699 - val_loss: 774556800.0000 - val_root_mean_squared_error: 27830.8613 - 294ms/epoch - 16ms/step
# Epoch 9/200
# 18/18 - 0s - loss: 684578432.0000 - root_mean_squared_error: 26164.4492 - val_loss: 752093824.0000 - val_root_mean_squared_error: 27424.3281 - 304ms/epoch - 17ms/step
# Epoch 10/200
# 18/18 - 0s - loss: 659344128.0000 - root_mean_squared_error: 25677.6973 - val_loss: 726728832.0000 - val_root_mean_squared_error: 26957.9082 - 301ms/epoch - 17ms/step
# Epoch 11/200
# 18/18 - 0s - loss: 646074624.0000 - root_mean_squared_error: 25417.9980 - val_loss: 702863232.0000 - val_root_mean_squared_error: 26511.5684 - 318ms/epoch - 18ms/step
# Epoch 12/200
# 18/18 - 0s - loss: 617735104.0000 - root_mean_squared_error: 24854.2773 - val_loss: 689481216.0000 - val_root_mean_squared_error: 26257.9746 - 412ms/epoch - 23ms/step
# Epoch 13/200
# 18/18 - 0s - loss: 599769600.0000 - root_mean_squared_error: 24490.1934 - val_loss: 685812864.0000 - val_root_mean_squared_error: 26188.0293 - 327ms/epoch - 18ms/step
# Epoch 14/200
# 18/18 - 0s - loss: 589436864.0000 - root_mean_squared_error: 24278.3203 - val_loss: 668405504.0000 - val_root_mean_squared_error: 25853.5391 - 331ms/epoch - 18ms/step
# Epoch 15/200
# 18/18 - 0s - loss: 580455424.0000 - root_mean_squared_error: 24092.6426 - val_loss: 658771520.0000 - val_root_mean_squared_error: 25666.5449 - 351ms/epoch - 19ms/step
# Epoch 16/200
# 18/18 - 0s - loss: 564739904.0000 - root_mean_squared_error: 23764.2578 - val_loss: 662065728.0000 - val_root_mean_squared_error: 25730.6387 - 353ms/epoch - 20ms/step
# Epoch 17/200
# 18/18 - 0s - loss: 555515520.0000 - root_mean_squared_error: 23569.3770 - val_loss: 647010368.0000 - val_root_mean_squared_error: 25436.3984 - 339ms/epoch - 19ms/step
# Epoch 18/200
# 18/18 - 0s - loss: 544956288.0000 - root_mean_squared_error: 23344.2988 - val_loss: 647841344.0000 - val_root_mean_squared_error: 25452.7285 - 410ms/epoch - 23ms/step
# Epoch 19/200
# 18/18 - 0s - loss: 544404608.0000 - root_mean_squared_error: 23332.4805 - val_loss: 636756544.0000 - val_root_mean_squared_error: 25234.0352 - 492ms/epoch - 27ms/step
# Epoch 20/200
# 18/18 - 1s - loss: 531807808.0000 - root_mean_squared_error: 23060.9590 - val_loss: 670176640.0000 - val_root_mean_squared_error: 25887.7695 - 584ms/epoch - 32ms/step
# Epoch 21/200
# 18/18 - 1s - loss: 531728672.0000 - root_mean_squared_error: 23059.2422 - val_loss: 636759552.0000 - val_root_mean_squared_error: 25234.0957 - 574ms/epoch - 32ms/step
# Epoch 22/200
# 18/18 - 1s - loss: 515286624.0000 - root_mean_squared_error: 22699.9258 - val_loss: 628029888.0000 - val_root_mean_squared_error: 25060.5254 - 564ms/epoch - 31ms/step
# Epoch 23/200
# 18/18 - 1s - loss: 512606112.0000 - root_mean_squared_error: 22640.8066 - val_loss: 620060032.0000 - val_root_mean_squared_error: 24901.0039 - 546ms/epoch - 30ms/step
# Epoch 24/200
# 18/18 - 1s - loss: 505522624.0000 - root_mean_squared_error: 22483.8301 - val_loss: 622203712.0000 - val_root_mean_squared_error: 24944.0117 - 556ms/epoch - 31ms/step
# Epoch 25/200
# 18/18 - 1s - loss: 501046752.0000 - root_mean_squared_error: 22384.0742 - val_loss: 624466688.0000 - val_root_mean_squared_error: 24989.3320 - 540ms/epoch - 30ms/step
# Epoch 26/200
# 18/18 - 1s - loss: 495532800.0000 - root_mean_squared_error: 22260.5664 - val_loss: 614555776.0000 - val_root_mean_squared_error: 24790.2363 - 538ms/epoch - 30ms/step
# Epoch 27/200
# 18/18 - 1s - loss: 493371392.0000 - root_mean_squared_error: 22211.9648 - val_loss: 609458816.0000 - val_root_mean_squared_error: 24687.2188 - 534ms/epoch - 30ms/step
# Epoch 28/200
# 18/18 - 1s - loss: 480568704.0000 - root_mean_squared_error: 21921.8770 - val_loss: 616010240.0000 - val_root_mean_squared_error: 24819.5527 - 624ms/epoch - 35ms/step
# Epoch 29/200
# 18/18 - 1s - loss: 482685376.0000 - root_mean_squared_error: 21970.1016 - val_loss: 616316544.0000 - val_root_mean_squared_error: 24825.7227 - 645ms/epoch - 36ms/step
# Epoch 30/200
# 18/18 - 1s - loss: 475473344.0000 - root_mean_squared_error: 21805.3516 - val_loss: 609216896.0000 - val_root_mean_squared_error: 24682.3203 - 562ms/epoch - 31ms/step
# Epoch 31/200
# 18/18 - 1s - loss: 468199328.0000 - root_mean_squared_error: 21637.9141 - val_loss: 620993728.0000 - val_root_mean_squared_error: 24919.7461 - 538ms/epoch - 30ms/step
# Epoch 32/200
# 18/18 - 1s - loss: 467825824.0000 - root_mean_squared_error: 21629.2812 - val_loss: 606839104.0000 - val_root_mean_squared_error: 24634.1035 - 580ms/epoch - 32ms/step
# Epoch 33/200
# 18/18 - 1s - loss: 467943936.0000 - root_mean_squared_error: 21632.0117 - val_loss: 605187968.0000 - val_root_mean_squared_error: 24600.5684 - 544ms/epoch - 30ms/step
# Epoch 34/200
# 18/18 - 1s - loss: 462770720.0000 - root_mean_squared_error: 21512.1055 - val_loss: 605341440.0000 - val_root_mean_squared_error: 24603.6875 - 590ms/epoch - 33ms/step
# Epoch 35/200
# 18/18 - 1s - loss: 457917824.0000 - root_mean_squared_error: 21399.0137 - val_loss: 596349312.0000 - val_root_mean_squared_error: 24420.2637 - 573ms/epoch - 32ms/step
# Epoch 36/200
# 18/18 - 1s - loss: 449832544.0000 - root_mean_squared_error: 21209.2559 - val_loss: 598606272.0000 - val_root_mean_squared_error: 24466.4316 - 534ms/epoch - 30ms/step
# Epoch 37/200
# 18/18 - 1s - loss: 447605792.0000 - root_mean_squared_error: 21156.6953 - val_loss: 592067328.0000 - val_root_mean_squared_error: 24332.4336 - 606ms/epoch - 34ms/step
# Epoch 38/200
# 18/18 - 1s - loss: 444989088.0000 - root_mean_squared_error: 21094.7637 - val_loss: 601835584.0000 - val_root_mean_squared_error: 24532.3379 - 521ms/epoch - 29ms/step
# Epoch 39/200
# 18/18 - 1s - loss: 438572288.0000 - root_mean_squared_error: 20942.1172 - val_loss: 588392832.0000 - val_root_mean_squared_error: 24256.8105 - 512ms/epoch - 28ms/step
# Epoch 40/200
# 18/18 - 0s - loss: 430508672.0000 - root_mean_squared_error: 20748.7031 - val_loss: 602051776.0000 - val_root_mean_squared_error: 24536.7441 - 496ms/epoch - 28ms/step
# Epoch 41/200
# 18/18 - 0s - loss: 437068128.0000 - root_mean_squared_error: 20906.1738 - val_loss: 608761216.0000 - val_root_mean_squared_error: 24673.0859 - 491ms/epoch - 27ms/step
# Epoch 42/200
# 18/18 - 0s - loss: 438936608.0000 - root_mean_squared_error: 20950.8145 - val_loss: 605849600.0000 - val_root_mean_squared_error: 24614.0117 - 486ms/epoch - 27ms/step
# Epoch 43/200
# 18/18 - 1s - loss: 434280160.0000 - root_mean_squared_error: 20839.3887 - val_loss: 575551104.0000 - val_root_mean_squared_error: 23990.6465 - 503ms/epoch - 28ms/step
# Epoch 44/200
# 18/18 - 0s - loss: 420154464.0000 - root_mean_squared_error: 20497.6699 - val_loss: 575556096.0000 - val_root_mean_squared_error: 23990.7500 - 479ms/epoch - 27ms/step
# Epoch 45/200
# 18/18 - 0s - loss: 415852416.0000 - root_mean_squared_error: 20392.4590 - val_loss: 584500736.0000 - val_root_mean_squared_error: 24176.4492 - 497ms/epoch - 28ms/step
# Epoch 46/200
# 18/18 - 0s - loss: 418045984.0000 - root_mean_squared_error: 20446.1719 - val_loss: 575692096.0000 - val_root_mean_squared_error: 23993.5840 - 483ms/epoch - 27ms/step
# Epoch 47/200
# 18/18 - 0s - loss: 420296384.0000 - root_mean_squared_error: 20501.1309 - val_loss: 572053440.0000 - val_root_mean_squared_error: 23917.6387 - 493ms/epoch - 27ms/step
# Epoch 48/200
# 18/18 - 0s - loss: 409477536.0000 - root_mean_squared_error: 20235.5508 - val_loss: 579231168.0000 - val_root_mean_squared_error: 24067.2227 - 490ms/epoch - 27ms/step
# Epoch 49/200
# 18/18 - 0s - loss: 405799328.0000 - root_mean_squared_error: 20144.4609 - val_loss: 629461504.0000 - val_root_mean_squared_error: 25089.0723 - 480ms/epoch - 27ms/step
# Epoch 50/200
# 18/18 - 0s - loss: 430972032.0000 - root_mean_squared_error: 20759.8652 - val_loss: 598379264.0000 - val_root_mean_squared_error: 24461.7910 - 484ms/epoch - 27ms/step
# Epoch 51/200
# 18/18 - 0s - loss: 416295840.0000 - root_mean_squared_error: 20403.3301 - val_loss: 585382016.0000 - val_root_mean_squared_error: 24194.6699 - 478ms/epoch - 27ms/step
# Epoch 52/200
# 18/18 - 0s - loss: 410843040.0000 - root_mean_squared_error: 20269.2637 - val_loss: 571314112.0000 - val_root_mean_squared_error: 23902.1777 - 492ms/epoch - 27ms/step
# Epoch 53/200
# 18/18 - 0s - loss: 395815424.0000 - root_mean_squared_error: 19895.1113 - val_loss: 571751616.0000 - val_root_mean_squared_error: 23911.3281 - 480ms/epoch - 27ms/step
# Epoch 54/200
# 18/18 - 1s - loss: 394854656.0000 - root_mean_squared_error: 19870.9492 - val_loss: 574723328.0000 - val_root_mean_squared_error: 23973.3887 - 528ms/epoch - 29ms/step
# Epoch 55/200
# 18/18 - 1s - loss: 389720000.0000 - root_mean_squared_error: 19741.3281 - val_loss: 569219008.0000 - val_root_mean_squared_error: 23858.3105 - 646ms/epoch - 36ms/step
# Epoch 56/200
# 18/18 - 0s - loss: 400299648.0000 - root_mean_squared_error: 20007.4902 - val_loss: 570348608.0000 - val_root_mean_squared_error: 23881.9727 - 496ms/epoch - 28ms/step
# Epoch 57/200
# 18/18 - 0s - loss: 386443616.0000 - root_mean_squared_error: 19658.1699 - val_loss: 567366976.0000 - val_root_mean_squared_error: 23819.4668 - 481ms/epoch - 27ms/step
# Epoch 58/200
# 18/18 - 0s - loss: 399313120.0000 - root_mean_squared_error: 19982.8203 - val_loss: 574939008.0000 - val_root_mean_squared_error: 23977.8867 - 465ms/epoch - 26ms/step
# Epoch 59/200
# 18/18 - 0s - loss: 396692736.0000 - root_mean_squared_error: 19917.1465 - val_loss: 562203648.0000 - val_root_mean_squared_error: 23710.8340 - 478ms/epoch - 27ms/step
# Epoch 60/200
# 18/18 - 0s - loss: 382989664.0000 - root_mean_squared_error: 19570.1211 - val_loss: 562179456.0000 - val_root_mean_squared_error: 23710.3242 - 478ms/epoch - 27ms/step
# Epoch 61/200
# 18/18 - 0s - loss: 387863936.0000 - root_mean_squared_error: 19694.2617 - val_loss: 560641792.0000 - val_root_mean_squared_error: 23677.8750 - 473ms/epoch - 26ms/step
# Epoch 62/200
# 18/18 - 0s - loss: 402128160.0000 - root_mean_squared_error: 20053.1328 - val_loss: 566647168.0000 - val_root_mean_squared_error: 23804.3516 - 474ms/epoch - 26ms/step
# Epoch 63/200
# 18/18 - 0s - loss: 383413568.0000 - root_mean_squared_error: 19580.9492 - val_loss: 557029760.0000 - val_root_mean_squared_error: 23601.4785 - 473ms/epoch - 26ms/step
# Epoch 64/200
# 18/18 - 0s - loss: 377165792.0000 - root_mean_squared_error: 19420.7559 - val_loss: 555487808.0000 - val_root_mean_squared_error: 23568.7891 - 480ms/epoch - 27ms/step
# Epoch 65/200
# 18/18 - 0s - loss: 373024384.0000 - root_mean_squared_error: 19313.8398 - val_loss: 557619200.0000 - val_root_mean_squared_error: 23613.9629 - 480ms/epoch - 27ms/step
# Epoch 66/200
# 18/18 - 0s - loss: 370571136.0000 - root_mean_squared_error: 19250.2246 - val_loss: 552115776.0000 - val_root_mean_squared_error: 23497.1445 - 480ms/epoch - 27ms/step
# Epoch 67/200
# 18/18 - 0s - loss: 369077216.0000 - root_mean_squared_error: 19211.3828 - val_loss: 555398272.0000 - val_root_mean_squared_error: 23566.8887 - 473ms/epoch - 26ms/step
# Epoch 68/200
# 18/18 - 0s - loss: 366648832.0000 - root_mean_squared_error: 19148.0762 - val_loss: 560298624.0000 - val_root_mean_squared_error: 23670.6270 - 473ms/epoch - 26ms/step
# Epoch 69/200
# 18/18 - 0s - loss: 368631328.0000 - root_mean_squared_error: 19199.7734 - val_loss: 556723904.0000 - val_root_mean_squared_error: 23594.9980 - 474ms/epoch - 26ms/step
# Epoch 70/200
# 18/18 - 0s - loss: 366036992.0000 - root_mean_squared_error: 19132.0938 - val_loss: 552454592.0000 - val_root_mean_squared_error: 23504.3535 - 465ms/epoch - 26ms/step
# Epoch 71/200
# 18/18 - 0s - loss: 367777824.0000 - root_mean_squared_error: 19177.5352 - val_loss: 552641024.0000 - val_root_mean_squared_error: 23508.3184 - 468ms/epoch - 26ms/step
# 45/45 [==============================] - 0s 4ms/step
# rmse=0.11, r2=0.92

# %% [markdown]
# ## Test data evaluation

# %%
X_test = pd.read_csv('test.csv')
X_test_scaled = preprocessor.transform(X_test)
Y_test_predict = model.predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 X_test = pd.read_csv('test.csv')
# ----> 2 X_test_scaled = preprocessor.transform(X_test)
#       3 Y_test_predict = model.predict(X_test_scaled)
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:1014, in ColumnTransformer.transform(self, X, **params)
#    1011 else:
#    1012     routed_params = self._get_empty_routing()
# -> 1014 Xs = self._call_func_on_transformers(
#    1015     X,
#    1016     None,
#    1017     _transform_one,
#    1018     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1019     routed_params=routed_params,
#    1020 )
#    1021 self._validate_output(Xs)
#    1023 if not Xs:
#    1024     # All transformers are None
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:823, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     811             extra_args = {}
#     812         jobs.append(
#     813             delayed(func)(
#     814                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     820             )
#     821         )
# --> 823     return Parallel(n_jobs=self.n_jobs)(jobs)
#     825 except ValueError as e:
#     826     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/pipeline.py:1283, in _transform_one(transformer, X, y, weight, params)
#    1261 def _transform_one(transformer, X, y, weight, params):
#    1262     """Call transform and apply weight to output.
#    1263
#    1264     Parameters
#    (...)
#    1281         This should be of the form ``process_routing()["step_name"]``.
#    1282     """
# -> 1283     res = transformer.transform(X, **params.transform)
#    1284     # if we have a weight for this transformer, multiply output
#    1285     if weight is None:
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/pipeline.py:905, in Pipeline.transform(self, X, **params)
#     903 Xt = X
#     904 for _, name, transform in self._iter():
# --> 905     Xt = transform.transform(Xt, **routed_params[name].transform)
#     906 return Xt
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:1577, in OrdinalEncoder.transform(self, X)
#    1563 """
#    1564 Transform X to ordinal codes.
#    1565
#    (...)
#    1574     Transformed input.
#    1575 """
#    1576 check_is_fitted(self, "categories_")
# -> 1577 X_int, X_mask = self._transform(
#    1578     X,
#    1579     handle_unknown=self.handle_unknown,
#    1580     force_all_finite="allow-nan",
#    1581     ignore_category_indices=self._missing_indices,
#    1582 )
#    1583 X_trans = X_int.astype(self.dtype, copy=False)
#    1585 for cat_idx, missing_idx in self._missing_indices.items():
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:213, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     208 if handle_unknown == "error":
#     209     msg = (
#     210         "Found unknown categories {0} in column {1}"
#     211         " during transform".format(diff, i)
#     212     )
# --> 213     raise ValueError(msg)
#     214 else:
#     215     if warn_on_unknown:
#
# ValueError: Found unknown categories [nan] in column 3 during transform
