# %% [markdown]
# # House price prediction model with random forest

# %%
# %pip install pipenv
# %pip install scikit-learn
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install tensorflow
# %pip install xgboost
# %pip install ipympl
# %matplotlib widget

# %%
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score
from xgboost import XGBRegressor
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
train_dataset = pd.read_csv('train.csv')
train_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
X_all = train_dataset.iloc[:,:-1]
Y_all = train_dataset.iloc[:,-1] # 1d vector

# %% [markdown]
# ## Features selection

# %%
selected_numerical_features = [
    'OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea',
    'LotArea', 'GrLivArea',
    'YearRemodAdd', 'TotRmsAbvGrd',
    'WoodDeckSF', 
]

one_hot_features = [
'MSZoning',
'LotShape',
'LandContour',
'LotConfig',
'LandSlope',
'Neighborhood',
'BldgType',
'HouseStyle',
# 'RoofStyle',
# 'Exterior1st',
# 'Exterior2nd',
# 'Foundation',
# 'CentralAir',
# 'Electrical',
# 'GarageType',
'GarageFinish',
'SaleType',
# 'SaleCondition',
# 'RoofMatl' #Missing ['ClyTile', 'Metal'] in train data
# 'BldgType'
]

ordinal_values_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
ordinal_features = [
    'ExterQual',
    'ExterCond',
    # 'HeatingQC',
    # 'KitchenQual'
]
ordinal_value_per_feature = len(ordinal_features)*[ordinal_values_order]

# %% [markdown]
# ## Preprocessing transformer

# %%
def build_preprocessor():
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler(),
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
            encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder()
    )
    transformer = ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    return transformer

# %% [markdown]
# ## Finding the best parameters for random forest regressor with grid cross-validation

# %%
min_samples_split_list = [2,10, 30, 50]  ## If the number is an integer, then it is the actual quantity of samples,
                                             ## If it is a float, then it is the percentage of the dataset
max_depth_list = [16, 32, 64, None]
n_estimators_list = [10,50,100,500]
param_grid = {
    'min_samples_split': min_samples_split_list,
    'n_estimators': n_estimators_list,
    'max_depth': max_depth_list
}

p = build_preprocessor()
X_train_scaled = p.fit_transform(X_all)

# %%
model = GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=2, verbose=3)
model.fit(X_train_scaled, Y_all)

print('Best params:', model.best_params_)
print('Best score:', model.best_score_)

Y_all_predict = model.predict(X_train_scaled)
rmse_log_score = root_mean_squared_error(np.log(X_train_scaled+0.001), np.log(Y_all_predict+0.001))
print(f'RMSE-log score: {rmse_log_score}')
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END max_depth=16, min_samples_split=2, n_estimators=10;, score=0.819 total time=   0.2s
# [CV 2/5] END max_depth=16, min_samples_split=2, n_estimators=10;, score=0.844 total time=   0.2s
# [CV 3/5] END max_depth=16, min_samples_split=2, n_estimators=10;, score=0.846 total time=   0.2s
# [CV 4/5] END max_depth=16, min_samples_split=2, n_estimators=10;, score=0.847 total time=   0.2s
# [CV 5/5] END max_depth=16, min_samples_split=2, n_estimators=10;, score=0.778 total time=   0.2s
# [CV 1/5] END max_depth=16, min_samples_split=2, n_estimators=50;, score=0.854 total time=   1.0s
# [CV 2/5] END max_depth=16, min_samples_split=2, n_estimators=50;, score=0.836 total time=   0.9s
# [CV 3/5] END max_depth=16, min_samples_split=2, n_estimators=50;, score=0.860 total time=   0.9s
# [CV 4/5] END max_depth=16, min_samples_split=2, n_estimators=50;, score=0.867 total time=   0.9s
# [CV 5/5] END max_depth=16, min_samples_split=2, n_estimators=50;, score=0.799 total time=   1.0s
# [CV 1/5] END max_depth=16, min_samples_split=2, n_estimators=100;, score=0.855 total time=   1.9s
# [CV 2/5] END max_depth=16, min_samples_split=2, n_estimators=100;, score=0.827 total time=   2.1s
# [CV 3/5] END max_depth=16, min_samples_split=2, n_estimators=100;, score=0.865 total time=   4.5s
# [CV 4/5] END max_depth=16, min_samples_split=2, n_estimators=100;, score=0.865 total time=   5.7s
# [CV 5/5] END max_depth=16, min_samples_split=2, n_estimators=100;, score=0.793 total time=   4.3s
# [CV 1/5] END max_depth=16, min_samples_split=2, n_estimators=500;, score=0.859 total time=  18.9s
# [CV 2/5] END max_depth=16, min_samples_split=2, n_estimators=500;, score=0.832 total time=  18.5s
# [CV 3/5] END max_depth=16, min_samples_split=2, n_estimators=500;, score=0.863 total time=  17.3s
# [CV 4/5] END max_depth=16, min_samples_split=2, n_estimators=500;, score=0.864 total time=  17.7s
# [CV 1/5] END max_depth=16, min_samples_split=10, n_estimators=10;, score=0.852 total time=   0.3s
# [CV 2/5] END max_depth=16, min_samples_split=10, n_estimators=10;, score=0.848 total time=   0.2s
# [CV 3/5] END max_depth=16, min_samples_split=10, n_estimators=10;, score=0.849 total time=   0.2s
# [CV 4/5] END max_depth=16, min_samples_split=10, n_estimators=10;, score=0.851 total time=   0.2s
# [CV 5/5] END max_depth=16, min_samples_split=10, n_estimators=10;, score=0.789 total time=   0.2s
# [CV 1/5] END max_depth=16, min_samples_split=10, n_estimators=50;, score=0.855 total time=   1.1s
# [CV 2/5] END max_depth=16, min_samples_split=10, n_estimators=50;, score=0.814 total time=   1.4s
# [CV 3/5] END max_depth=16, min_samples_split=10, n_estimators=50;, score=0.856 total time=   1.2s
# [CV 4/5] END max_depth=16, min_samples_split=10, n_estimators=50;, score=0.852 total time=   1.1s
# [CV 5/5] END max_depth=16, min_samples_split=10, n_estimators=50;, score=0.807 total time=   1.0s
# [CV 1/5] END max_depth=16, min_samples_split=10, n_estimators=100;, score=0.857 total time=   2.1s
# [CV 2/5] END max_depth=16, min_samples_split=10, n_estimators=100;, score=0.827 total time=   1.9s
# [CV 3/5] END max_depth=16, min_samples_split=10, n_estimators=100;, score=0.850 total time=   2.0s
# [CV 4/5] END max_depth=16, min_samples_split=10, n_estimators=100;, score=0.859 total time=   2.1s
# [CV 5/5] END max_depth=16, min_samples_split=2, n_estimators=500;, score=0.804 total time=  17.9s
# [CV 5/5] END max_depth=16, min_samples_split=10, n_estimators=100;, score=0.794 total time=   2.1s
# [CV 1/5] END max_depth=16, min_samples_split=10, n_estimators=500;, score=0.861 total time=  10.8s
# [CV 2/5] END max_depth=16, min_samples_split=10, n_estimators=500;, score=0.825 total time=  11.1s
# [CV 3/5] END max_depth=16, min_samples_split=10, n_estimators=500;, score=0.856 total time=  11.1s
# [CV 4/5] END max_depth=16, min_samples_split=10, n_estimators=500;, score=0.861 total time=  10.8s
# [CV 1/5] END max_depth=16, min_samples_split=30, n_estimators=10;, score=0.826 total time=   0.2s
# [CV 2/5] END max_depth=16, min_samples_split=30, n_estimators=10;, score=0.821 total time=   0.2s
# [CV 3/5] END max_depth=16, min_samples_split=30, n_estimators=10;, score=0.802 total time=   0.1s
# [CV 4/5] END max_depth=16, min_samples_split=30, n_estimators=10;, score=0.839 total time=   0.1s
# [CV 5/5] END max_depth=16, min_samples_split=30, n_estimators=10;, score=0.759 total time=   0.1s
# [CV 1/5] END max_depth=16, min_samples_split=30, n_estimators=50;, score=0.844 total time=   0.7s
# [CV 2/5] END max_depth=16, min_samples_split=30, n_estimators=50;, score=0.826 total time=   0.6s
# [CV 3/5] END max_depth=16, min_samples_split=30, n_estimators=50;, score=0.815 total time=   0.5s
# [CV 4/5] END max_depth=16, min_samples_split=30, n_estimators=50;, score=0.831 total time=   0.5s
# [CV 5/5] END max_depth=16, min_samples_split=30, n_estimators=50;, score=0.761 total time=   0.5s
# [CV 1/5] END max_depth=16, min_samples_split=30, n_estimators=100;, score=0.847 total time=   1.0s
# [CV 2/5] END max_depth=16, min_samples_split=30, n_estimators=100;, score=0.826 total time=   1.0s
# [CV 3/5] END max_depth=16, min_samples_split=30, n_estimators=100;, score=0.814 total time=   1.0s
# [CV 4/5] END max_depth=16, min_samples_split=30, n_estimators=100;, score=0.827 total time=   1.1s
# [CV 5/5] END max_depth=16, min_samples_split=10, n_estimators=500;, score=0.794 total time=   9.9s
# [CV 5/5] END max_depth=16, min_samples_split=30, n_estimators=100;, score=0.759 total time=   1.4s
# [CV 1/5] END max_depth=16, min_samples_split=30, n_estimators=500;, score=0.851 total time=   6.1s
# [CV 2/5] END max_depth=16, min_samples_split=30, n_estimators=500;, score=0.832 total time=   6.0s
# [CV 3/5] END max_depth=16, min_samples_split=30, n_estimators=500;, score=0.813 total time=   6.6s
# [CV 4/5] END max_depth=16, min_samples_split=30, n_estimators=500;, score=0.836 total time=   6.4s
# [CV 1/5] END max_depth=16, min_samples_split=50, n_estimators=10;, score=0.827 total time=   0.1s
# [CV 2/5] END max_depth=16, min_samples_split=50, n_estimators=10;, score=0.810 total time=   0.1s
# [CV 3/5] END max_depth=16, min_samples_split=50, n_estimators=10;, score=0.771 total time=   0.1s
# [CV 4/5] END max_depth=16, min_samples_split=50, n_estimators=10;, score=0.808 total time=   0.1s
# [CV 5/5] END max_depth=16, min_samples_split=50, n_estimators=10;, score=0.713 total time=   0.1s
# [CV 1/5] END max_depth=16, min_samples_split=50, n_estimators=50;, score=0.830 total time=   0.6s
# [CV 2/5] END max_depth=16, min_samples_split=50, n_estimators=50;, score=0.816 total time=   0.5s
# [CV 3/5] END max_depth=16, min_samples_split=50, n_estimators=50;, score=0.762 total time=   0.5s
# [CV 4/5] END max_depth=16, min_samples_split=50, n_estimators=50;, score=0.811 total time=   0.6s
# [CV 5/5] END max_depth=16, min_samples_split=50, n_estimators=50;, score=0.742 total time=   0.5s
# [CV 1/5] END max_depth=16, min_samples_split=50, n_estimators=100;, score=0.834 total time=   1.1s
# [CV 2/5] END max_depth=16, min_samples_split=50, n_estimators=100;, score=0.822 total time=   1.0s
# [CV 3/5] END max_depth=16, min_samples_split=50, n_estimators=100;, score=0.766 total time=   1.1s
# [CV 5/5] END max_depth=16, min_samples_split=30, n_estimators=500;, score=0.764 total time=   6.8s
# [CV 5/5] END max_depth=16, min_samples_split=50, n_estimators=100;, score=0.740 total time=   1.0s
# [CV 4/5] END max_depth=16, min_samples_split=50, n_estimators=100;, score=0.811 total time=   1.0s
# [CV 1/5] END max_depth=16, min_samples_split=50, n_estimators=500;, score=0.836 total time=   4.8s
# [CV 2/5] END max_depth=16, min_samples_split=50, n_estimators=500;, score=0.824 total time=   5.0s
# [CV 3/5] END max_depth=16, min_samples_split=50, n_estimators=500;, score=0.762 total time=   5.7s
# [CV 4/5] END max_depth=16, min_samples_split=50, n_estimators=500;, score=0.816 total time=   5.9s
# [CV 1/5] END max_depth=32, min_samples_split=2, n_estimators=10;, score=0.824 total time=   0.6s
# [CV 2/5] END max_depth=32, min_samples_split=2, n_estimators=10;, score=0.778 total time=   0.6s
# [CV 3/5] END max_depth=32, min_samples_split=2, n_estimators=10;, score=0.859 total time=   0.7s
# [CV 4/5] END max_depth=32, min_samples_split=2, n_estimators=10;, score=0.837 total time=   0.5s
# [CV 5/5] END max_depth=32, min_samples_split=2, n_estimators=10;, score=0.762 total time=   0.5s
# [CV 1/5] END max_depth=32, min_samples_split=2, n_estimators=50;, score=0.860 total time=   2.3s
# [CV 5/5] END max_depth=16, min_samples_split=50, n_estimators=500;, score=0.740 total time=   6.3s
# [CV 2/5] END max_depth=32, min_samples_split=2, n_estimators=50;, score=0.816 total time=   2.6s
# [CV 3/5] END max_depth=32, min_samples_split=2, n_estimators=50;, score=0.864 total time=   2.8s
# [CV 4/5] END max_depth=32, min_samples_split=2, n_estimators=50;, score=0.858 total time=   2.9s
# [CV 5/5] END max_depth=32, min_samples_split=2, n_estimators=50;, score=0.811 total time=   2.7s
# [CV 1/5] END max_depth=32, min_samples_split=2, n_estimators=100;, score=0.859 total time=   5.6s
# [CV 2/5] END max_depth=32, min_samples_split=2, n_estimators=100;, score=0.833 total time=   5.5s
# [CV 3/5] END max_depth=32, min_samples_split=2, n_estimators=100;, score=0.870 total time=   4.7s
# [CV 4/5] END max_depth=32, min_samples_split=2, n_estimators=100;, score=0.862 total time=   4.7s
# [CV 5/5] END max_depth=32, min_samples_split=2, n_estimators=100;, score=0.796 total time=   5.4s
# [CV 1/5] END max_depth=32, min_samples_split=2, n_estimators=500;, score=0.860 total time=  20.0s
# [CV 2/5] END max_depth=32, min_samples_split=2, n_estimators=500;, score=0.828 total time=  18.8s
# [CV 3/5] END max_depth=32, min_samples_split=2, n_estimators=500;, score=0.866 total time=  19.3s
# [CV 4/5] END max_depth=32, min_samples_split=2, n_estimators=500;, score=0.864 total time=  19.0s
# [CV 1/5] END max_depth=32, min_samples_split=10, n_estimators=10;, score=0.845 total time=   0.2s
# [CV 2/5] END max_depth=32, min_samples_split=10, n_estimators=10;, score=0.819 total time=   0.2s
# [CV 3/5] END max_depth=32, min_samples_split=10, n_estimators=10;, score=0.841 total time=   0.2s
# [CV 4/5] END max_depth=32, min_samples_split=10, n_estimators=10;, score=0.834 total time=   0.2s
# [CV 5/5] END max_depth=32, min_samples_split=10, n_estimators=10;, score=0.796 total time=   0.2s
# [CV 1/5] END max_depth=32, min_samples_split=10, n_estimators=50;, score=0.858 total time=   0.9s
# [CV 2/5] END max_depth=32, min_samples_split=10, n_estimators=50;, score=0.830 total time=   1.0s
# [CV 3/5] END max_depth=32, min_samples_split=10, n_estimators=50;, score=0.841 total time=   1.3s
# [CV 4/5] END max_depth=32, min_samples_split=10, n_estimators=50;, score=0.858 total time=   1.3s
# [CV 5/5] END max_depth=32, min_samples_split=10, n_estimators=50;, score=0.782 total time=   1.5s
# [CV 1/5] END max_depth=32, min_samples_split=10, n_estimators=100;, score=0.864 total time=   2.5s
# [CV 2/5] END max_depth=32, min_samples_split=10, n_estimators=100;, score=0.819 total time=   3.3s
# [CV 3/5] END max_depth=32, min_samples_split=10, n_estimators=100;, score=0.847 total time=   2.3s
# [CV 5/5] END max_depth=32, min_samples_split=2, n_estimators=500;, score=0.810 total time=  19.9s
# [CV 4/5] END max_depth=32, min_samples_split=10, n_estimators=100;, score=0.860 total time=   2.5s
# [CV 5/5] END max_depth=32, min_samples_split=10, n_estimators=100;, score=0.789 total time=   3.2s
# [CV 1/5] END max_depth=32, min_samples_split=10, n_estimators=500;, score=0.858 total time=  16.3s
# [CV 2/5] END max_depth=32, min_samples_split=10, n_estimators=500;, score=0.829 total time=  15.4s
# [CV 3/5] END max_depth=32, min_samples_split=10, n_estimators=500;, score=0.854 total time=   9.8s
# [CV 4/5] END max_depth=32, min_samples_split=10, n_estimators=500;, score=0.863 total time=   9.7s
# [CV 1/5] END max_depth=32, min_samples_split=30, n_estimators=10;, score=0.841 total time=   0.1s
# [CV 2/5] END max_depth=32, min_samples_split=30, n_estimators=10;, score=0.814 total time=   0.1s
# [CV 3/5] END max_depth=32, min_samples_split=30, n_estimators=10;, score=0.816 total time=   0.1s
# [CV 4/5] END max_depth=32, min_samples_split=30, n_estimators=10;, score=0.833 total time=   0.1s
# [CV 5/5] END max_depth=32, min_samples_split=30, n_estimators=10;, score=0.761 total time=   0.1s
# [CV 1/5] END max_depth=32, min_samples_split=30, n_estimators=50;, score=0.850 total time=   0.6s
# [CV 2/5] END max_depth=32, min_samples_split=30, n_estimators=50;, score=0.833 total time=   0.6s
# [CV 3/5] END max_depth=32, min_samples_split=30, n_estimators=50;, score=0.818 total time=   0.6s
# [CV 4/5] END max_depth=32, min_samples_split=30, n_estimators=50;, score=0.840 total time=   0.5s
# [CV 5/5] END max_depth=32, min_samples_split=30, n_estimators=50;, score=0.757 total time=   0.5s
# [CV 1/5] END max_depth=32, min_samples_split=30, n_estimators=100;, score=0.848 total time=   1.0s
# [CV 2/5] END max_depth=32, min_samples_split=30, n_estimators=100;, score=0.831 total time=   1.1s
# [CV 3/5] END max_depth=32, min_samples_split=30, n_estimators=100;, score=0.816 total time=   1.1s
# [CV 4/5] END max_depth=32, min_samples_split=30, n_estimators=100;, score=0.837 total time=   1.1s
# [CV 5/5] END max_depth=32, min_samples_split=10, n_estimators=500;, score=0.799 total time=  10.0s
# [CV 5/5] END max_depth=32, min_samples_split=30, n_estimators=100;, score=0.759 total time=   1.4s
# [CV 1/5] END max_depth=32, min_samples_split=30, n_estimators=500;, score=0.848 total time=   7.4s
# [CV 2/5] END max_depth=32, min_samples_split=30, n_estimators=500;, score=0.832 total time=   7.3s
# [CV 3/5] END max_depth=32, min_samples_split=30, n_estimators=500;, score=0.810 total time=   7.9s
# [CV 4/5] END max_depth=32, min_samples_split=30, n_estimators=500;, score=0.836 total time=   7.9s
# [CV 1/5] END max_depth=32, min_samples_split=50, n_estimators=10;, score=0.827 total time=   0.1s
# [CV 2/5] END max_depth=32, min_samples_split=50, n_estimators=10;, score=0.793 total time=   0.1s
# [CV 3/5] END max_depth=32, min_samples_split=50, n_estimators=10;, score=0.746 total time=   0.1s
# [CV 4/5] END max_depth=32, min_samples_split=50, n_estimators=10;, score=0.791 total time=   0.1s
# [CV 5/5] END max_depth=32, min_samples_split=50, n_estimators=10;, score=0.722 total time=   0.1s
# [CV 1/5] END max_depth=32, min_samples_split=50, n_estimators=50;, score=0.826 total time=   0.4s
# [CV 2/5] END max_depth=32, min_samples_split=50, n_estimators=50;, score=0.816 total time=   0.4s
# [CV 3/5] END max_depth=32, min_samples_split=50, n_estimators=50;, score=0.758 total time=   0.4s
# [CV 4/5] END max_depth=32, min_samples_split=50, n_estimators=50;, score=0.815 total time=   0.4s
# [CV 5/5] END max_depth=32, min_samples_split=50, n_estimators=50;, score=0.735 total time=   0.4s
# [CV 1/5] END max_depth=32, min_samples_split=50, n_estimators=100;, score=0.833 total time=   0.8s
# [CV 2/5] END max_depth=32, min_samples_split=50, n_estimators=100;, score=0.815 total time=   0.8s
# [CV 3/5] END max_depth=32, min_samples_split=50, n_estimators=100;, score=0.758 total time=   0.7s
# [CV 5/5] END max_depth=32, min_samples_split=30, n_estimators=500;, score=0.763 total time=   5.3s
# [CV 4/5] END max_depth=32, min_samples_split=50, n_estimators=100;, score=0.812 total time=   0.8s
# [CV 5/5] END max_depth=32, min_samples_split=50, n_estimators=100;, score=0.738 total time=   0.8s
# [CV 1/5] END max_depth=32, min_samples_split=50, n_estimators=500;, score=0.834 total time=   4.3s
# [CV 2/5] END max_depth=32, min_samples_split=50, n_estimators=500;, score=0.823 total time=   4.5s
# [CV 3/5] END max_depth=32, min_samples_split=50, n_estimators=500;, score=0.764 total time=   4.8s
# [CV 4/5] END max_depth=32, min_samples_split=50, n_estimators=500;, score=0.814 total time=   4.8s
# [CV 1/5] END max_depth=64, min_samples_split=2, n_estimators=10;, score=0.838 total time=   0.3s
# [CV 2/5] END max_depth=64, min_samples_split=2, n_estimators=10;, score=0.824 total time=   0.3s
# [CV 3/5] END max_depth=64, min_samples_split=2, n_estimators=10;, score=0.850 total time=   0.3s
# [CV 4/5] END max_depth=64, min_samples_split=2, n_estimators=10;, score=0.840 total time=   0.3s
# [CV 5/5] END max_depth=64, min_samples_split=2, n_estimators=10;, score=0.769 total time=   0.3s
# [CV 1/5] END max_depth=64, min_samples_split=2, n_estimators=50;, score=0.863 total time=   1.5s
# [CV 5/5] END max_depth=32, min_samples_split=50, n_estimators=500;, score=0.738 total time=   3.9s
# [CV 2/5] END max_depth=64, min_samples_split=2, n_estimators=50;, score=0.820 total time=   1.8s
# [CV 3/5] END max_depth=64, min_samples_split=2, n_estimators=50;, score=0.859 total time=   1.8s
# [CV 4/5] END max_depth=64, min_samples_split=2, n_estimators=50;, score=0.865 total time=   1.9s
# [CV 5/5] END max_depth=64, min_samples_split=2, n_estimators=50;, score=0.807 total time=   1.9s
# [CV 1/5] END max_depth=64, min_samples_split=2, n_estimators=100;, score=0.862 total time=   3.5s
# [CV 2/5] END max_depth=64, min_samples_split=2, n_estimators=100;, score=0.825 total time=   3.5s
# [CV 3/5] END max_depth=64, min_samples_split=2, n_estimators=100;, score=0.873 total time=   5.3s
# [CV 4/5] END max_depth=64, min_samples_split=2, n_estimators=100;, score=0.865 total time=   5.5s
# [CV 5/5] END max_depth=64, min_samples_split=2, n_estimators=100;, score=0.809 total time=   5.1s
# [CV 1/5] END max_depth=64, min_samples_split=2, n_estimators=500;, score=0.860 total time=  26.3s
# [CV 2/5] END max_depth=64, min_samples_split=2, n_estimators=500;, score=0.829 total time=  26.3s
# [CV 3/5] END max_depth=64, min_samples_split=2, n_estimators=500;, score=0.862 total time=  25.8s
# [CV 4/5] END max_depth=64, min_samples_split=2, n_estimators=500;, score=0.864 total time=  25.3s
# [CV 1/5] END max_depth=64, min_samples_split=10, n_estimators=10;, score=0.825 total time=   0.3s
# [CV 2/5] END max_depth=64, min_samples_split=10, n_estimators=10;, score=0.802 total time=   0.3s
# [CV 3/5] END max_depth=64, min_samples_split=10, n_estimators=10;, score=0.845 total time=   0.4s
# [CV 4/5] END max_depth=64, min_samples_split=10, n_estimators=10;, score=0.853 total time=   0.3s
# [CV 5/5] END max_depth=64, min_samples_split=10, n_estimators=10;, score=0.810 total time=   0.3s
# [CV 1/5] END max_depth=64, min_samples_split=10, n_estimators=50;, score=0.859 total time=   1.5s
# [CV 2/5] END max_depth=64, min_samples_split=10, n_estimators=50;, score=0.819 total time=   1.5s
# [CV 3/5] END max_depth=64, min_samples_split=10, n_estimators=50;, score=0.841 total time=   1.8s
# [CV 4/5] END max_depth=64, min_samples_split=10, n_estimators=50;, score=0.860 total time=   1.6s
# [CV 5/5] END max_depth=64, min_samples_split=10, n_estimators=50;, score=0.784 total time=   1.7s
# [CV 1/5] END max_depth=64, min_samples_split=10, n_estimators=100;, score=0.858 total time=   3.1s
# [CV 2/5] END max_depth=64, min_samples_split=10, n_estimators=100;, score=0.829 total time=   3.3s
# [CV 3/5] END max_depth=64, min_samples_split=10, n_estimators=100;, score=0.859 total time=   3.3s
# [CV 5/5] END max_depth=64, min_samples_split=2, n_estimators=500;, score=0.806 total time=  26.4s
# [CV 4/5] END max_depth=64, min_samples_split=10, n_estimators=100;, score=0.860 total time=   3.2s
# [CV 5/5] END max_depth=64, min_samples_split=10, n_estimators=100;, score=0.797 total time=   2.2s
# [CV 1/5] END max_depth=64, min_samples_split=10, n_estimators=500;, score=0.860 total time=  12.3s
# [CV 2/5] END max_depth=64, min_samples_split=10, n_estimators=500;, score=0.823 total time=  12.2s
# [CV 3/5] END max_depth=64, min_samples_split=10, n_estimators=500;, score=0.855 total time=   8.9s
# [CV 4/5] END max_depth=64, min_samples_split=10, n_estimators=500;, score=0.861 total time=   8.9s
# [CV 1/5] END max_depth=64, min_samples_split=30, n_estimators=10;, score=0.847 total time=   0.1s
# [CV 2/5] END max_depth=64, min_samples_split=30, n_estimators=10;, score=0.813 total time=   0.1s
# [CV 3/5] END max_depth=64, min_samples_split=30, n_estimators=10;, score=0.817 total time=   0.1s
# [CV 4/5] END max_depth=64, min_samples_split=30, n_estimators=10;, score=0.801 total time=   0.1s
# [CV 5/5] END max_depth=64, min_samples_split=30, n_estimators=10;, score=0.733 total time=   0.1s
# [CV 1/5] END max_depth=64, min_samples_split=30, n_estimators=50;, score=0.847 total time=   0.5s
# [CV 2/5] END max_depth=64, min_samples_split=30, n_estimators=50;, score=0.834 total time=   0.5s
# [CV 3/5] END max_depth=64, min_samples_split=30, n_estimators=50;, score=0.820 total time=   0.5s
# [CV 4/5] END max_depth=64, min_samples_split=30, n_estimators=50;, score=0.830 total time=   0.5s
# [CV 5/5] END max_depth=64, min_samples_split=30, n_estimators=50;, score=0.763 total time=   0.5s
# [CV 1/5] END max_depth=64, min_samples_split=30, n_estimators=100;, score=0.851 total time=   1.0s
# [CV 2/5] END max_depth=64, min_samples_split=30, n_estimators=100;, score=0.837 total time=   1.0s
# [CV 3/5] END max_depth=64, min_samples_split=30, n_estimators=100;, score=0.814 total time=   1.0s
# [CV 4/5] END max_depth=64, min_samples_split=30, n_estimators=100;, score=0.833 total time=   1.0s
# [CV 5/5] END max_depth=64, min_samples_split=10, n_estimators=500;, score=0.795 total time=   8.9s
# [CV 5/5] END max_depth=64, min_samples_split=30, n_estimators=100;, score=0.759 total time=   1.0s
# [CV 1/5] END max_depth=64, min_samples_split=30, n_estimators=500;, score=0.851 total time=   5.1s
# [CV 2/5] END max_depth=64, min_samples_split=30, n_estimators=500;, score=0.831 total time=   5.1s
# [CV 3/5] END max_depth=64, min_samples_split=30, n_estimators=500;, score=0.815 total time=   5.1s
# [CV 4/5] END max_depth=64, min_samples_split=30, n_estimators=500;, score=0.835 total time=   5.1s
# [CV 1/5] END max_depth=64, min_samples_split=50, n_estimators=10;, score=0.822 total time=   0.1s
# [CV 2/5] END max_depth=64, min_samples_split=50, n_estimators=10;, score=0.816 total time=   0.1s
# [CV 3/5] END max_depth=64, min_samples_split=50, n_estimators=10;, score=0.763 total time=   0.1s
# [CV 4/5] END max_depth=64, min_samples_split=50, n_estimators=10;, score=0.798 total time=   0.1s
# [CV 5/5] END max_depth=64, min_samples_split=50, n_estimators=10;, score=0.735 total time=   0.1s
# [CV 1/5] END max_depth=64, min_samples_split=50, n_estimators=50;, score=0.831 total time=   0.4s
# [CV 2/5] END max_depth=64, min_samples_split=50, n_estimators=50;, score=0.820 total time=   0.4s
# [CV 3/5] END max_depth=64, min_samples_split=50, n_estimators=50;, score=0.762 total time=   0.4s
# [CV 4/5] END max_depth=64, min_samples_split=50, n_estimators=50;, score=0.808 total time=   0.4s
# [CV 5/5] END max_depth=64, min_samples_split=50, n_estimators=50;, score=0.733 total time=   0.4s
# [CV 1/5] END max_depth=64, min_samples_split=50, n_estimators=100;, score=0.838 total time=   0.8s
# [CV 2/5] END max_depth=64, min_samples_split=50, n_estimators=100;, score=0.824 total time=   0.7s
# [CV 5/5] END max_depth=64, min_samples_split=30, n_estimators=500;, score=0.762 total time=   5.1s
# [CV 3/5] END max_depth=64, min_samples_split=50, n_estimators=100;, score=0.760 total time=   0.7s
# [CV 4/5] END max_depth=64, min_samples_split=50, n_estimators=100;, score=0.812 total time=   0.7s
# [CV 5/5] END max_depth=64, min_samples_split=50, n_estimators=100;, score=0.742 total time=   0.8s
# [CV 1/5] END max_depth=64, min_samples_split=50, n_estimators=500;, score=0.835 total time=   3.7s
# [CV 2/5] END max_depth=64, min_samples_split=50, n_estimators=500;, score=0.825 total time=   3.8s
# [CV 3/5] END max_depth=64, min_samples_split=50, n_estimators=500;, score=0.761 total time=   4.0s
# [CV 4/5] END max_depth=64, min_samples_split=50, n_estimators=500;, score=0.813 total time=   4.1s
# [CV 1/5] END max_depth=None, min_samples_split=2, n_estimators=10;, score=0.861 total time=   0.3s
# [CV 2/5] END max_depth=None, min_samples_split=2, n_estimators=10;, score=0.740 total time=   0.3s
# [CV 3/5] END max_depth=None, min_samples_split=2, n_estimators=10;, score=0.851 total time=   0.3s
# [CV 4/5] END max_depth=None, min_samples_split=2, n_estimators=10;, score=0.842 total time=   0.3s
# [CV 5/5] END max_depth=None, min_samples_split=2, n_estimators=10;, score=0.797 total time=   0.3s
# [CV 1/5] END max_depth=None, min_samples_split=2, n_estimators=50;, score=0.857 total time=   1.5s
# [CV 5/5] END max_depth=64, min_samples_split=50, n_estimators=500;, score=0.741 total time=   3.8s
# [CV 2/5] END max_depth=None, min_samples_split=2, n_estimators=50;, score=0.818 total time=   1.5s
# [CV 3/5] END max_depth=None, min_samples_split=2, n_estimators=50;, score=0.865 total time=   1.5s
# [CV 4/5] END max_depth=None, min_samples_split=2, n_estimators=50;, score=0.865 total time=   1.5s
# [CV 5/5] END max_depth=None, min_samples_split=2, n_estimators=50;, score=0.800 total time=   1.5s
# [CV 1/5] END max_depth=None, min_samples_split=2, n_estimators=100;, score=0.861 total time=   2.9s
# [CV 2/5] END max_depth=None, min_samples_split=2, n_estimators=100;, score=0.818 total time=   2.9s
# [CV 3/5] END max_depth=None, min_samples_split=2, n_estimators=100;, score=0.867 total time=   2.9s
# [CV 4/5] END max_depth=None, min_samples_split=2, n_estimators=100;, score=0.858 total time=   2.9s
# [CV 5/5] END max_depth=None, min_samples_split=2, n_estimators=100;, score=0.798 total time=   2.9s
# [CV 1/5] END max_depth=None, min_samples_split=2, n_estimators=500;, score=0.861 total time=  14.6s
# [CV 2/5] END max_depth=None, min_samples_split=2, n_estimators=500;, score=0.826 total time=  14.5s
# [CV 3/5] END max_depth=None, min_samples_split=2, n_estimators=500;, score=0.864 total time=  14.5s
# [CV 4/5] END max_depth=None, min_samples_split=2, n_estimators=500;, score=0.865 total time=  14.5s
# [CV 1/5] END max_depth=None, min_samples_split=10, n_estimators=10;, score=0.838 total time=   0.2s
# [CV 2/5] END max_depth=None, min_samples_split=10, n_estimators=10;, score=0.826 total time=   0.2s
# [CV 3/5] END max_depth=None, min_samples_split=10, n_estimators=10;, score=0.856 total time=   0.2s
# [CV 4/5] END max_depth=None, min_samples_split=10, n_estimators=10;, score=0.857 total time=   0.2s
# [CV 5/5] END max_depth=None, min_samples_split=10, n_estimators=10;, score=0.784 total time=   0.2s
# [CV 1/5] END max_depth=None, min_samples_split=10, n_estimators=50;, score=0.856 total time=   0.9s
# [CV 2/5] END max_depth=None, min_samples_split=10, n_estimators=50;, score=0.823 total time=   0.9s
# [CV 3/5] END max_depth=None, min_samples_split=10, n_estimators=50;, score=0.862 total time=   0.9s
# [CV 4/5] END max_depth=None, min_samples_split=10, n_estimators=50;, score=0.863 total time=   0.9s
# [CV 5/5] END max_depth=None, min_samples_split=10, n_estimators=50;, score=0.790 total time=   0.9s
# [CV 1/5] END max_depth=None, min_samples_split=10, n_estimators=100;, score=0.856 total time=   1.8s
# [CV 2/5] END max_depth=None, min_samples_split=10, n_estimators=100;, score=0.831 total time=   1.8s
# [CV 3/5] END max_depth=None, min_samples_split=10, n_estimators=100;, score=0.853 total time=   1.8s
# [CV 5/5] END max_depth=None, min_samples_split=2, n_estimators=500;, score=0.805 total time=  14.6s
# [CV 4/5] END max_depth=None, min_samples_split=10, n_estimators=100;, score=0.858 total time=   1.8s
# [CV 5/5] END max_depth=None, min_samples_split=10, n_estimators=100;, score=0.787 total time=   1.8s
# [CV 1/5] END max_depth=None, min_samples_split=10, n_estimators=500;, score=0.857 total time=   8.8s
# [CV 2/5] END max_depth=None, min_samples_split=10, n_estimators=500;, score=0.832 total time=   8.8s
# [CV 3/5] END max_depth=None, min_samples_split=10, n_estimators=500;, score=0.852 total time=   9.0s
# [CV 4/5] END max_depth=None, min_samples_split=10, n_estimators=500;, score=0.864 total time=   9.0s
# [CV 1/5] END max_depth=None, min_samples_split=30, n_estimators=10;, score=0.844 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_split=30, n_estimators=10;, score=0.824 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_split=30, n_estimators=10;, score=0.801 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_split=30, n_estimators=10;, score=0.830 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_split=30, n_estimators=10;, score=0.736 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_split=30, n_estimators=50;, score=0.848 total time=   0.5s
# [CV 2/5] END max_depth=None, min_samples_split=30, n_estimators=50;, score=0.834 total time=   0.5s
# [CV 3/5] END max_depth=None, min_samples_split=30, n_estimators=50;, score=0.817 total time=   0.5s
# [CV 4/5] END max_depth=None, min_samples_split=30, n_estimators=50;, score=0.837 total time=   0.5s
# [CV 5/5] END max_depth=None, min_samples_split=30, n_estimators=50;, score=0.754 total time=   0.5s
# [CV 1/5] END max_depth=None, min_samples_split=30, n_estimators=100;, score=0.850 total time=   1.0s
# [CV 2/5] END max_depth=None, min_samples_split=30, n_estimators=100;, score=0.830 total time=   1.0s
# [CV 3/5] END max_depth=None, min_samples_split=30, n_estimators=100;, score=0.813 total time=   1.0s
# [CV 4/5] END max_depth=None, min_samples_split=30, n_estimators=100;, score=0.829 total time=   1.0s
# [CV 5/5] END max_depth=None, min_samples_split=10, n_estimators=500;, score=0.799 total time=   9.0s
# [CV 5/5] END max_depth=None, min_samples_split=30, n_estimators=100;, score=0.761 total time=   1.0s
# [CV 1/5] END max_depth=None, min_samples_split=30, n_estimators=500;, score=0.852 total time=   5.0s
# [CV 2/5] END max_depth=None, min_samples_split=30, n_estimators=500;, score=0.831 total time=   5.0s
# [CV 3/5] END max_depth=None, min_samples_split=30, n_estimators=500;, score=0.817 total time=   5.0s
# [CV 4/5] END max_depth=None, min_samples_split=30, n_estimators=500;, score=0.834 total time=   5.0s
# [CV 1/5] END max_depth=None, min_samples_split=50, n_estimators=10;, score=0.829 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_split=50, n_estimators=10;, score=0.820 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_split=50, n_estimators=10;, score=0.767 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_split=50, n_estimators=10;, score=0.810 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_split=50, n_estimators=10;, score=0.728 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_split=50, n_estimators=50;, score=0.835 total time=   0.4s
# [CV 2/5] END max_depth=None, min_samples_split=50, n_estimators=50;, score=0.821 total time=   0.4s
# [CV 3/5] END max_depth=None, min_samples_split=50, n_estimators=50;, score=0.761 total time=   0.4s
# [CV 4/5] END max_depth=None, min_samples_split=50, n_estimators=50;, score=0.814 total time=   0.4s
# [CV 5/5] END max_depth=None, min_samples_split=50, n_estimators=50;, score=0.730 total time=   0.4s
# [CV 1/5] END max_depth=None, min_samples_split=50, n_estimators=100;, score=0.830 total time=   0.7s
# [CV 2/5] END max_depth=None, min_samples_split=50, n_estimators=100;, score=0.825 total time=   0.7s
# [CV 5/5] END max_depth=None, min_samples_split=30, n_estimators=500;, score=0.763 total time=   5.1s
# [CV 3/5] END max_depth=None, min_samples_split=50, n_estimators=100;, score=0.764 total time=   0.7s
# [CV 4/5] END max_depth=None, min_samples_split=50, n_estimators=100;, score=0.814 total time=   0.8s
# [CV 5/5] END max_depth=None, min_samples_split=50, n_estimators=100;, score=0.744 total time=   0.7s
# [CV 1/5] END max_depth=None, min_samples_split=50, n_estimators=500;, score=0.835 total time=   3.7s
# [CV 2/5] END max_depth=None, min_samples_split=50, n_estimators=500;, score=0.823 total time=   3.8s
# [CV 3/5] END max_depth=None, min_samples_split=50, n_estimators=500;, score=0.762 total time=   3.7s
# [CV 4/5] END max_depth=None, min_samples_split=50, n_estimators=500;, score=0.813 total time=   3.7s
# [CV 5/5] END max_depth=None, min_samples_split=50, n_estimators=500;, score=0.737 total time=   3.0s
# Best params: {'max_depth': 64, 'min_samples_split': 2, 'n_estimators': 100}
# Best score: 0.8465052523050204
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 8
#       5 print('Best score:', model.best_score_)
#       7 Y_all_predict = model.predict(X_train_scaled)
# ----> 8 rmse_log_score = root_mean_squared_error(np.log(X_train_scaled+0.001), np.log(Y_all_predict+0.001))
#       9 print(f'RMSE-log score: {rmse_log_score}')
#
# File ~/anaconda3/envs/house-price-prediction-experiments/lib/python3.11/site-packages/scipy/sparse/_base.py:516, in _spbase.__add__(self, other)
#     514         return self.copy()
#     515     # Now we would add this scalar to every element.
# --> 516     raise NotImplementedError('adding a nonzero scalar to a '
#     517                               'sparse array is not supported')
#     518 elif issparse(other):
#     519     if other.shape != self.shape:
#
# NotImplementedError: adding a nonzero scalar to a sparse array is not supported

# %% [markdown]
# Best params: {'max_depth': 64, 'min_samples_split': 2, 'n_estimators': 500}
#
# Best score: 0.8460436374790623

# %% [markdown]
# ### Finding the best parameters for boosted trees

# %%
param_grid = {
    'n_estimators': n_estimators_list,
    'max_depth': max_depth_list
}
xmodel = GridSearchCV(XGBRegressor(), param_grid, n_jobs=2, verbose=3)
xmodel.fit(X_train_scaled, Y_all)
print('Best params:', xmodel.best_params_)
print('Best score:', xmodel.best_score_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 2/5] END .....max_depth=16, n_estimators=10;, score=0.773 total time=   0.1s
# [CV 1/5] END .....max_depth=16, n_estimators=10;, score=0.822 total time=   0.3s
# [CV 3/5] END .....max_depth=16, n_estimators=10;, score=0.805 total time=   0.2s
# [CV 4/5] END .....max_depth=16, n_estimators=10;, score=0.845 total time=   0.1s
# [CV 5/5] END .....max_depth=16, n_estimators=10;, score=0.767 total time=   0.1s
# [CV 2/5] END .....max_depth=16, n_estimators=50;, score=0.764 total time=   0.3s
# [CV 1/5] END .....max_depth=16, n_estimators=50;, score=0.820 total time=   0.3s
# [CV 3/5] END .....max_depth=16, n_estimators=50;, score=0.820 total time=   0.3s
# [CV 4/5] END .....max_depth=16, n_estimators=50;, score=0.848 total time=   0.3s
# [CV 5/5] END .....max_depth=16, n_estimators=50;, score=0.784 total time=   0.3s
# [CV 1/5] END ....max_depth=16, n_estimators=100;, score=0.820 total time=   0.8s
# [CV 3/5] END ....max_depth=16, n_estimators=100;, score=0.820 total time=   0.5s
# [CV 4/5] END ....max_depth=16, n_estimators=100;, score=0.848 total time=   0.5s
# [CV 2/5] END ....max_depth=16, n_estimators=100;, score=0.764 total time=   0.8s
# [CV 5/5] END ....max_depth=16, n_estimators=100;, score=0.784 total time=   0.6s
# [CV 2/5] END ....max_depth=16, n_estimators=500;, score=0.764 total time=   2.2s
# [CV 1/5] END ....max_depth=16, n_estimators=500;, score=0.820 total time=   5.5s
# [CV 3/5] END ....max_depth=16, n_estimators=500;, score=0.820 total time=   6.5s
# [CV 1/5] END .....max_depth=32, n_estimators=10;, score=0.823 total time=   0.3s
# [CV 2/5] END .....max_depth=32, n_estimators=10;, score=0.772 total time=   0.3s
# [CV 3/5] END .....max_depth=32, n_estimators=10;, score=0.804 total time=   0.3s
# [CV 4/5] END .....max_depth=32, n_estimators=10;, score=0.848 total time=   0.3s
# [CV 5/5] END .....max_depth=32, n_estimators=10;, score=0.766 total time=   0.2s
# [CV 1/5] END .....max_depth=32, n_estimators=50;, score=0.819 total time=   1.2s
# [CV 4/5] END ....max_depth=16, n_estimators=500;, score=0.848 total time=   5.5s
# [CV 2/5] END .....max_depth=32, n_estimators=50;, score=0.766 total time=   1.5s
# [CV 3/5] END .....max_depth=32, n_estimators=50;, score=0.819 total time=   2.9s
# [CV 4/5] END .....max_depth=32, n_estimators=50;, score=0.848 total time=   2.1s
# [CV 5/5] END ....max_depth=16, n_estimators=500;, score=0.784 total time=   7.3s
# [CV 5/5] END .....max_depth=32, n_estimators=50;, score=0.782 total time=   1.3s
# [CV 2/5] END ....max_depth=32, n_estimators=100;, score=0.766 total time=   2.5s
# [CV 1/5] END ....max_depth=32, n_estimators=100;, score=0.819 total time=   2.9s
# [CV 3/5] END ....max_depth=32, n_estimators=100;, score=0.819 total time=   2.3s
# [CV 4/5] END ....max_depth=32, n_estimators=100;, score=0.848 total time=   2.2s
# [CV 5/5] END ....max_depth=32, n_estimators=100;, score=0.782 total time=   3.2s
# [CV 1/5] END ....max_depth=32, n_estimators=500;, score=0.819 total time=  10.0s
# [CV 2/5] END ....max_depth=32, n_estimators=500;, score=0.766 total time=  11.6s
# [CV 3/5] END ....max_depth=32, n_estimators=500;, score=0.819 total time=  13.6s
# [CV 4/5] END ....max_depth=32, n_estimators=500;, score=0.848 total time=  10.7s
# [CV 1/5] END .....max_depth=64, n_estimators=10;, score=0.823 total time=   0.2s
# [CV 2/5] END .....max_depth=64, n_estimators=10;, score=0.772 total time=   0.2s
# [CV 3/5] END .....max_depth=64, n_estimators=10;, score=0.804 total time=   0.2s
# [CV 4/5] END .....max_depth=64, n_estimators=10;, score=0.848 total time=   0.2s
# [CV 5/5] END .....max_depth=64, n_estimators=10;, score=0.766 total time=   0.2s
# [CV 1/5] END .....max_depth=64, n_estimators=50;, score=0.819 total time=   1.2s
# [CV 2/5] END .....max_depth=64, n_estimators=50;, score=0.766 total time=   1.4s
# [CV 3/5] END .....max_depth=64, n_estimators=50;, score=0.819 total time=   1.7s
# [CV 4/5] END .....max_depth=64, n_estimators=50;, score=0.848 total time=   1.5s
# [CV 5/5] END ....max_depth=32, n_estimators=500;, score=0.782 total time=   9.4s
# [CV 5/5] END .....max_depth=64, n_estimators=50;, score=0.782 total time=   1.7s
# [CV 1/5] END ....max_depth=64, n_estimators=100;, score=0.819 total time=   2.6s
# [CV 2/5] END ....max_depth=64, n_estimators=100;, score=0.766 total time=   2.7s
# [CV 3/5] END ....max_depth=64, n_estimators=100;, score=0.819 total time=   3.0s
# [CV 4/5] END ....max_depth=64, n_estimators=100;, score=0.848 total time=   2.9s
# [CV 5/5] END ....max_depth=64, n_estimators=100;, score=0.782 total time=   2.1s
# [CV 1/5] END ....max_depth=64, n_estimators=500;, score=0.819 total time=  10.8s
# [CV 2/5] END ....max_depth=64, n_estimators=500;, score=0.766 total time=  10.0s
# [CV 3/5] END ....max_depth=64, n_estimators=500;, score=0.819 total time=  13.8s
# [CV 4/5] END ....max_depth=64, n_estimators=500;, score=0.848 total time=  13.7s
# [CV 1/5] END ...max_depth=None, n_estimators=10;, score=0.835 total time=   0.1s
# [CV 2/5] END ...max_depth=None, n_estimators=10;, score=0.789 total time=   0.1s
# [CV 3/5] END ...max_depth=None, n_estimators=10;, score=0.843 total time=   0.1s
# [CV 4/5] END ...max_depth=None, n_estimators=10;, score=0.836 total time=   0.1s
# [CV 5/5] END ...max_depth=None, n_estimators=10;, score=0.788 total time=   0.1s
# [CV 1/5] END ...max_depth=None, n_estimators=50;, score=0.843 total time=   1.1s
# [CV 2/5] END ...max_depth=None, n_estimators=50;, score=0.787 total time=   0.3s
# [CV 3/5] END ...max_depth=None, n_estimators=50;, score=0.850 total time=   0.3s
# [CV 4/5] END ...max_depth=None, n_estimators=50;, score=0.851 total time=   0.6s
# [CV 5/5] END ...max_depth=None, n_estimators=50;, score=0.817 total time=   0.3s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.842 total time=   0.5s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/5] END ..max_depth=None, n_estimators=100;, score=0.849 total time=   0.3s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.853 total time=   0.4s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.818 total time=   0.3s
# [CV 1/5] END ..max_depth=None, n_estimators=500;, score=0.842 total time=   1.9s
# [CV 2/5] END ..max_depth=None, n_estimators=500;, score=0.783 total time=   1.8s
# [CV 3/5] END ..max_depth=None, n_estimators=500;, score=0.848 total time=   2.6s
# [CV 4/5] END ..max_depth=None, n_estimators=500;, score=0.853 total time=   2.2s
# [CV 5/5] END ..max_depth=None, n_estimators=500;, score=0.819 total time=   1.0s
# [CV 5/5] END ....max_depth=64, n_estimators=500;, score=0.782 total time=  15.5s
# Best params: {'max_depth': None, 'n_estimators': 50}
# Best score: 0.8298275354431931

# %% [markdown]
# Best params: {'max_depth': None, 'n_estimators': 50}
#
# Best score: 0.8298275354431931
