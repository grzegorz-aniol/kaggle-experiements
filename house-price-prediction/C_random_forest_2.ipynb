# %% [markdown]
# # House price prediction model with random forest

# %%
# %pip install pipenv
# %pip install scikit-learn
# %pip install seaborn
# %pip install matplotlib
# %pip install numpy
# %pip install tensorflow
# %pip install xgboost
# %pip install ipympl
# %matplotlib widget

# %%
import math
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score
from xgboost import XGBRegressor
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
train_dataset = pd.read_csv('train.csv')
train_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
X_all = train_dataset.iloc[:,:-1]
Y_all = train_dataset.iloc[:,-1] # 1d vector

# %% [markdown]
# ## Features selection

# %%
selected_numerical_features = [
    'OverallQual', 'YearBuilt', 'Fireplaces', 'GarageArea',
    'LotArea', 'GrLivArea',
    'YearRemodAdd', 'TotRmsAbvGrd',
    'WoodDeckSF', 
]

one_hot_features = [
'MSZoning',
'LotShape',
'LandContour',
'LotConfig',
'LandSlope',
'Neighborhood',
'BldgType',
'HouseStyle',
# 'RoofStyle',
# 'Exterior1st',
# 'Exterior2nd',
# 'Foundation',
# 'CentralAir',
# 'Electrical',
# 'GarageType',
'GarageFinish',
'SaleType',
# 'SaleCondition',
# 'RoofMatl' #Missing ['ClyTile', 'Metal'] in train data
# 'BldgType'
]

ordinal_values_order = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
ordinal_features = [
    'ExterQual',
    'ExterCond',
    # 'HeatingQC',
    # 'KitchenQual'
]
ordinal_value_per_feature = len(ordinal_features)*[ordinal_values_order]

# %% [markdown]
# ## Preprocessing transformer

# %%
def build_preprocessor():
    numeric_transformer = make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler(),
    )
    numeric_transformer_2 = make_pipeline(
        SimpleImputer(strategy='constant', fill_value=0),
        StandardScaler() 
    )
    ordinal_encoder = make_pipeline(
        OrdinalEncoder(categories=ordinal_value_per_feature, 
            encoded_missing_value=ordinal_values_order.index('TA')),
        StandardScaler()
    )
    one_hot_encoded = make_pipeline(
        SimpleImputer(strategy='most_frequent'), OneHotEncoder(sparse_output=False)
    )
    transformer = ColumnTransformer(transformers=[
           ('numeric1', numeric_transformer, selected_numerical_features),
           ('numeric2', numeric_transformer_2, ['MasVnrArea']),
           ('one_hot', one_hot_encoded, one_hot_features),
           ('ordinal', ordinal_encoder, ordinal_features),
        ])
    return transformer

# %% [markdown]
# ## Finding the best parameters for random forest regressor with grid cross-validation

# %%
min_samples_split_list = [2,10, 30, 50]  ## If the number is an integer, then it is the actual quantity of samples,
                                             ## If it is a float, then it is the percentage of the dataset
max_depth_list = [16, 32, 64, None]
n_estimators_list = [10,50,100,500]
param_grid = {
    'min_samples_split': min_samples_split_list,
    'n_estimators': n_estimators_list,
    'max_depth': max_depth_list
}

p = build_preprocessor()
X_train_scaled = p.fit_transform(X_all)

# %%
from collections import namedtuple
Model = namedtuple('Model', ['model','score','rmse_log'])

# %%
def fit_model(model):
    model.fit(X_train_scaled, Y_all)
    if hasattr(model, 'best_params_'):
        print('Best params:', model.best_params_)
        print('Best score:', model.best_score_)
    Y_all_predict = model.predict(X_train_scaled)
    score = model.score(X_train_scaled, Y_all)
    rmse_log_score = root_mean_squared_error(np.log(Y_all+0.001), np.log(Y_all_predict+0.001))
    print(f'R2={score:.2f}, RMSE-LOG={rmse_log_score:.2f}')
    return Model(model=model, score=score, rmse_log=rmse_log_score)

# rf_model_grid = fit_model(model=GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=2, verbose=3))

# %%
best_rf_model =  fit_model(RandomForestRegressor(max_depth=64, min_samples_split=2, n_estimators=500))
print(f'R2={best_rf_model.score:.2f}, RMSE-LOG={best_rf_model.rmse_log:.2f}')
# Out:
# RMSE-log score: 0.06233802800278064
# R2=0.98, RMSE-LOG=0.06

# %% [markdown]
# ### Finding the best parameters for boosted trees

# %%
param_grid = {
    'n_estimators': n_estimators_list,
    'max_depth': max_depth_list
}

# xb_model_grid = fit_model(model=GridSearchCV(XGBRegressor(), param_grid, n_jobs=2, verbose=3))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 2/5] END .....max_depth=16, n_estimators=10;, score=0.773 total time=   0.1s
# [CV 1/5] END .....max_depth=16, n_estimators=10;, score=0.822 total time=   0.1s
# [CV 3/5] END .....max_depth=16, n_estimators=10;, score=0.805 total time=   0.1s
# [CV 4/5] END .....max_depth=16, n_estimators=10;, score=0.845 total time=   0.1s
# [CV 5/5] END .....max_depth=16, n_estimators=10;, score=0.767 total time=   0.1s
# [CV 1/5] END .....max_depth=16, n_estimators=50;, score=0.820 total time=   0.4s
# [CV 2/5] END .....max_depth=16, n_estimators=50;, score=0.764 total time=   0.4s
# [CV 3/5] END .....max_depth=16, n_estimators=50;, score=0.820 total time=   0.3s
# [CV 4/5] END .....max_depth=16, n_estimators=50;, score=0.848 total time=   0.4s
# [CV 5/5] END .....max_depth=16, n_estimators=50;, score=0.784 total time=   0.5s
# [CV 1/5] END ....max_depth=16, n_estimators=100;, score=0.820 total time=   0.7s
# [CV 2/5] END ....max_depth=16, n_estimators=100;, score=0.764 total time=   0.6s
# [CV 3/5] END ....max_depth=16, n_estimators=100;, score=0.820 total time=   0.6s
# [CV 5/5] END ....max_depth=16, n_estimators=100;, score=0.784 total time=   0.7s
# [CV 4/5] END ....max_depth=16, n_estimators=100;, score=0.848 total time=   1.2s
# [CV 2/5] END ....max_depth=16, n_estimators=500;, score=0.764 total time=   4.3s
# [CV 1/5] END ....max_depth=16, n_estimators=500;, score=0.820 total time=   7.1s
# [CV 3/5] END ....max_depth=16, n_estimators=500;, score=0.820 total time=   7.4s
# [CV 4/5] END ....max_depth=16, n_estimators=500;, score=0.848 total time=   5.2s
# [CV 1/5] END .....max_depth=32, n_estimators=10;, score=0.823 total time=   0.5s
# [CV 2/5] END .....max_depth=32, n_estimators=10;, score=0.772 total time=   0.7s
# [CV 3/5] END .....max_depth=32, n_estimators=10;, score=0.804 total time=   0.3s
# [CV 4/5] END .....max_depth=32, n_estimators=10;, score=0.848 total time=   0.2s
# [CV 5/5] END .....max_depth=32, n_estimators=10;, score=0.766 total time=   0.3s
# [CV 1/5] END .....max_depth=32, n_estimators=50;, score=0.819 total time=   2.5s
# [CV 5/5] END ....max_depth=16, n_estimators=500;, score=0.784 total time=   5.8s
# [CV 2/5] END .....max_depth=32, n_estimators=50;, score=0.766 total time=   1.3s
# [CV 3/5] END .....max_depth=32, n_estimators=50;, score=0.819 total time=   1.6s
# [CV 5/5] END .....max_depth=32, n_estimators=50;, score=0.782 total time=   1.1s
# [CV 4/5] END .....max_depth=32, n_estimators=50;, score=0.848 total time=   3.1s
# [CV 1/5] END ....max_depth=32, n_estimators=100;, score=0.819 total time=   3.8s
# [CV 2/5] END ....max_depth=32, n_estimators=100;, score=0.766 total time=   3.4s
# [CV 4/5] END ....max_depth=32, n_estimators=100;, score=0.848 total time=   2.6s
# [CV 3/5] END ....max_depth=32, n_estimators=100;, score=0.819 total time=   4.1s
# [CV 5/5] END ....max_depth=32, n_estimators=100;, score=0.782 total time=   2.5s
# [CV 1/5] END ....max_depth=32, n_estimators=500;, score=0.819 total time=  15.9s
# [CV 2/5] END ....max_depth=32, n_estimators=500;, score=0.766 total time=  16.4s
# [CV 3/5] END ....max_depth=32, n_estimators=500;, score=0.819 total time=  15.0s
# [CV 4/5] END ....max_depth=32, n_estimators=500;, score=0.848 total time=  19.3s
# [CV 1/5] END .....max_depth=64, n_estimators=10;, score=0.823 total time=   0.2s
# [CV 2/5] END .....max_depth=64, n_estimators=10;, score=0.772 total time=   0.3s
# [CV 3/5] END .....max_depth=64, n_estimators=10;, score=0.804 total time=   0.3s
# [CV 4/5] END .....max_depth=64, n_estimators=10;, score=0.848 total time=   0.4s
# [CV 5/5] END .....max_depth=64, n_estimators=10;, score=0.766 total time=   0.2s
# [CV 1/5] END .....max_depth=64, n_estimators=50;, score=0.819 total time=   1.7s
# [CV 2/5] END .....max_depth=64, n_estimators=50;, score=0.766 total time=   1.6s
# [CV 3/5] END .....max_depth=64, n_estimators=50;, score=0.819 total time=   1.2s
# [CV 4/5] END .....max_depth=64, n_estimators=50;, score=0.848 total time=   1.3s
# [CV 5/5] END .....max_depth=64, n_estimators=50;, score=0.782 total time=   1.1s
# [CV 1/5] END ....max_depth=64, n_estimators=100;, score=0.819 total time=   2.2s
# [CV 5/5] END ....max_depth=32, n_estimators=500;, score=0.782 total time=  17.4s
# [CV 2/5] END ....max_depth=64, n_estimators=100;, score=0.766 total time=   2.9s
# [CV 3/5] END ....max_depth=64, n_estimators=100;, score=0.819 total time=   3.8s
# [CV 4/5] END ....max_depth=64, n_estimators=100;, score=0.848 total time=   3.5s
# [CV 5/5] END ....max_depth=64, n_estimators=100;, score=0.782 total time=   3.5s
# [CV 1/5] END ....max_depth=64, n_estimators=500;, score=0.819 total time=  10.2s
# [CV 2/5] END ....max_depth=64, n_estimators=500;, score=0.766 total time=  14.5s
# [CV 3/5] END ....max_depth=64, n_estimators=500;, score=0.819 total time=  14.6s
# [CV 4/5] END ....max_depth=64, n_estimators=500;, score=0.848 total time=  13.8s
# [CV 1/5] END ...max_depth=None, n_estimators=10;, score=0.835 total time=   0.2s
# [CV 2/5] END ...max_depth=None, n_estimators=10;, score=0.789 total time=   0.2s
# [CV 3/5] END ...max_depth=None, n_estimators=10;, score=0.843 total time=   0.2s
# [CV 4/5] END ...max_depth=None, n_estimators=10;, score=0.836 total time=   0.8s
# [CV 5/5] END ...max_depth=None, n_estimators=10;, score=0.788 total time=   0.1s
# [CV 1/5] END ...max_depth=None, n_estimators=50;, score=0.843 total time=   0.2s
# [CV 2/5] END ...max_depth=None, n_estimators=50;, score=0.787 total time=   0.1s
# [CV 3/5] END ...max_depth=None, n_estimators=50;, score=0.850 total time=   0.2s
# [CV 4/5] END ...max_depth=None, n_estimators=50;, score=0.851 total time=   0.2s
# [CV 5/5] END ...max_depth=None, n_estimators=50;, score=0.817 total time=   0.6s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.842 total time=   0.3s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/5] END ..max_depth=None, n_estimators=100;, score=0.849 total time=   0.2s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.853 total time=   0.2s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.818 total time=   0.2s
# [CV 1/5] END ..max_depth=None, n_estimators=500;, score=0.842 total time=   1.8s
# [CV 5/5] END ....max_depth=64, n_estimators=500;, score=0.782 total time=  11.0s
# [CV 2/5] END ..max_depth=None, n_estimators=500;, score=0.783 total time=   1.2s
# [CV 3/5] END ..max_depth=None, n_estimators=500;, score=0.848 total time=   1.3s
# [CV 4/5] END ..max_depth=None, n_estimators=500;, score=0.853 total time=   1.2s
# [CV 5/5] END ..max_depth=None, n_estimators=500;, score=0.819 total time=   0.9s
# Best params: {'max_depth': None, 'n_estimators': 50}
# Best score: 0.8298275354431931
# RMSE-log score: 0.05170333152135962

# %%
best_xb_model = fit_model(XGBRegressor(max_depth=None, n_estimators=50))
# Out:
# R2=0.99, RMSE-LOG=0.05

# %% [markdown]
# ## Produce test prediction

# %%
X_test = pd.read_csv('test.csv')
X_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
X_test_scaled = p.transform(X_test)
Y_test_predict = best_xb_model.model.predict(X_test_scaled)

# %%
df_output = pd.DataFrame(data={'Id': X_test['Id'], 'SalePrice': Y_test_predict})
df_output.head()
# Out:
#      Id      SalePrice
# 0  1461  117282.984375
# 1  1462  142971.578125
# 2  1463  189735.531250
# 3  1464  180100.562500
# 4  1465  179582.296875

# %%
df_output.to_csv('./C_submission.csv', index=False)
